# %% [markdown]
# ## hindcast example

# %%
#to use the full width of the browser window
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from Poseidon.utils.cast import *

# %% [markdown]
# ### setup

# %%
#read the info from the first run
with open('/home/critechproc/STORAGE/EUR/20100201.00/info.pkl', 'r') as f:
              info=pickle.load(f)

# %%
#define some info
info.update({'path':'/home/critechproc/STORAGE/EUR/', # The path of the project
     'case':'European 2010', # a reference tag
     })

# %%
#creating a time sequence of the runs
start_date = datetime.datetime(2010,2,1,0)
end_date = datetime.datetime(2010,2,10,12)
time_interval = datetime.timedelta(hours=12)
        
dt=(end_date-start_date).total_seconds()
ndt=dt/time_interval.total_seconds()
ndt=np.int(ndt)+1

date_list = [start_date + time_interval*x for x in range(ndt)]

# %%
#append to dic
info.update({'start_date':start_date,'end_date':end_date, 'time_interval':time_interval,'dates' : date_list})

# %%
#creating a sequence of folder to store the runs. In this case we name them after the date attribute.
#NOTE that the first folder is the fisrt run already perfomed!!
folders = [datetime.datetime.strftime(x, '%Y%m%d.%H') for x in date_list]
info.update({'folders':folders})

# %%
#creating a sequence of folder from which we read the meteo.
PATH='/home/critechproc/STORAGE/meteo/'
meteo = [PATH+'{:04d}/{:02d}/{:02d}/'.format(x.year,x.month,x.day)+datetime.datetime.strftime(x, '%Y%m%d.%H')+'.tropical_cyclone.grib' for x in date_list]
info.update({'meteo_files':meteo})

# %%
#check
info['folders'],info['meteo_files']
# Out:
# (['20100201.00',
#   '20100201.12',
#   '20100202.00',
#   '20100202.12',
#   '20100203.00',
#   '20100203.12',
#   '20100204.00',
#   '20100204.12',
#   '20100205.00',
#   '20100205.12',
#   '20100206.00',
#   '20100206.12',
#   '20100207.00',
#   '20100207.12',
#   '20100208.00',
#   '20100208.12',
#   '20100209.00',
#   '20100209.12',
#   '20100210.00',
#   '20100210.12'],
#  ['/home/critechproc/STORAGE/meteo/2010/02/01/20100201.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/01/20100201.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/02/20100202.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/02/20100202.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/03/20100203.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/03/20100203.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/04/20100204.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/04/20100204.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/05/20100205.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/05/20100205.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/06/20100206.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/06/20100206.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/07/20100207.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/07/20100207.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/08/20100208.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/08/20100208.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/09/20100209.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/09/20100209.12.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/10/20100210.00.tropical_cyclone.grib',
#   '/home/critechproc/STORAGE/meteo/2010/02/10/20100210.12.tropical_cyclone.grib'])

# %%
#check dict
#info

# %% [markdown]
# ### run the hindcast

# %%
#set cast
h = cast(**info) # initialize

# %%
#info

# %%
h.run()
# Out:
# process meteo
# 100%|██████████| 39/39 [00:14<00:00,  2.81it/s]
# meteo done
# executing
# MPI process number 001 has host unknown and is running on processor 9a66a855f966
# MPI process number 002 has host unknown and is running on processor 9a66a855f966
# MPI process number 003 has host unknown and is running on processor 9a66a855f966
# MPI process number 007 has host unknown and is running on processor 9a66a855f966
# MPI process number 000 has host unknown and is running on processor 9a66a855f966
# MPI process number 004 has host unknown and is running on processor 9a66a855f966
# MPI process number 005 has host unknown and is running on processor 9a66a855f966
# MPI process number 006 has host unknown and is running on processor 9a66a855f966
# MPI process number 008 has host unknown and is running on processor 9a66a855f966
# MPI process number 009 has host unknown and is running on processor 9a66a855f966
# --------------------------------------------------------------------------------
#        Deltares, FLOW2D3D Version 6.02.10.6976, Feb  7 2017, 09:42:53
#        libflow2d3d.so entry Flow2D3D::Run
# --------------------------------------------------------------------------------
#
# Part I    - Initialisation Time Dep. Data module...
#             runid : test
# Part II   - Creating intermediate files...
# Part III  - Initialisation of the Execution module...
# Part IV   - Reading complete MD-file...
# Part V    - Initialisation & checking input...
# Part VI   - Initialisation & checking second part...
# Part VII  - Initialisation output...
# Part VIII - Start Simulation...
#
#   Time to finish   0s,    0.0% completed, time steps left  720
#   Time to finish  39m,    0.1% completed, time steps left  719
#   Time to finish  21m,    0.3% completed, time steps left  718
#   Time to finish  15m,    0.4% completed, time steps left  717
#   Time to finish  12m,    0.6% completed, time steps left  716
#   Time to finish   9m 43s,    0.7% completed, time steps left  715
#   Time to finish   8m 31s,    0.8% completed, time steps left  714
#   Time to finish   7m 39s,    1.0% completed, time steps left  713
#   Time to finish   7m  0s,    1.1% completed, time steps left  712
#   Time to finish   6m 30s,    1.2% completed, time steps left  711
#   Time to finish   6m  6s,    1.4% completed, time steps left  710
#   Time to finish   5m 45s,    1.5% completed, time steps left  709
#   Time to finish   5m 29s,    1.7% completed, time steps left  708
#   Time to finish   5m 15s,    1.8% completed, time steps left  707
#   Time to finish   5m  4s,    1.9% completed, time steps left  706
#   Time to finish   4m 53s,    2.1% completed, time steps left  705
#   Time to finish   4m 43s,    2.2% completed, time steps left  704
#   Time to finish   4m 35s,    2.4% completed, time steps left  703
#   Time to finish   4m 28s,    2.5% completed, time steps left  702
#   Time to finish   4m 21s,    2.6% completed, time steps left  701
#   Time to finish   4m 15s,    2.8% completed, time steps left  700
#   Time to finish   4m 10s,    2.9% completed, time steps left  699
#   Time to finish   4m  4s,    3.1% completed, time steps left  698
#   Time to finish   4m  0s,    3.2% completed, time steps left  697
#   Time to finish   3m 56s,    3.3% completed, time steps left  696
#   Time to finish   3m 52s,    3.5% completed, time steps left  695
#   Time to finish   3m 48s,    3.6% completed, time steps left  694
#   Time to finish   3m 45s,    3.8% completed, time steps left  693
#   Time to finish   3m 42s,    3.9% completed, time steps left  692
#   Time to finish   3m 39s,    4.0% completed, time steps left  691
#   Time to finish   3m 36s,    4.2% completed, time steps left  690
#   Time to finish   3m 34s,    4.3% completed, time steps left  689
#   Time to finish   3m 31s,    4.4% completed, time steps left  688
#   Time to finish   3m 29s,    4.6% completed, time steps left  687
#   Time to finish   3m 27s,    4.7% completed, time steps left  686
#   Time to finish   3m 25s,    4.9% completed, time steps left  685
#   Time to finish   3m 23s,    5.0% completed, time steps left  684
#   Time to finish   3m 21s,    5.1% completed, time steps left  683
#   Time to finish   3m 19s,    5.3% completed, time steps left  682
#   Time to finish   3m 18s,    5.4% completed, time steps left  681
#   Time to finish   3m 16s,    5.6% completed, time steps left  680
#   Time to finish   3m 14s,    5.7% completed, time steps left  679
#   Time to finish   3m 13s,    5.8% completed, time steps left  678
#   Time to finish   3m 12s,    6.0% completed, time steps left  677
#   Time to finish   3m 10s,    6.1% completed, time steps left  676
#   Time to finish   3m  9s,    6.2% completed, time steps left  675
#   Time to finish   3m  8s,    6.4% completed, time steps left  674
#   Time to finish   3m  6s,    6.5% completed, time steps left  673
#   Time to finish   3m  5s,    6.7% completed, time steps left  672
#   Time to finish   3m  4s,    6.8% completed, time steps left  671
#   Time to finish   3m  3s,    6.9% completed, time steps left  670
#   Time to finish   3m  2s,    7.1% completed, time steps left  669
#   Time to finish   3m  1s,    7.2% completed, time steps left  668
#   Time to finish   3m  0s,    7.4% completed, time steps left  667
#   Time to finish   2m 59s,    7.5% completed, time steps left  666
#   Time to finish   2m 58s,    7.6% completed, time steps left  665
#   Time to finish   2m 57s,    7.8% completed, time steps left  664
#   Time to finish   2m 56s,    7.9% completed, time steps left  663
#   Time to finish   2m 55s,    8.1% completed, time steps left  662
#   Time to finish   2m 54s,    8.2% completed, time steps left  661
#   Time to finish   2m 54s,    8.3% completed, time steps left  660
#   Time to finish   3m 31s,    8.5% completed, time steps left  659
#   Time to finish   3m 29s,    8.6% completed, time steps left  658
#   Time to finish   3m 28s,    8.8% completed, time steps left  657
#   Time to finish   3m 26s,    8.9% completed, time steps left  656
#   Time to finish   3m 25s,    9.0% completed, time steps left  655
#   Time to finish   3m 24s,    9.2% completed, time steps left  654
#   Time to finish   3m 22s,    9.3% completed, time steps left  653
#   Time to finish   3m 21s,    9.4% completed, time steps left  652
#   Time to finish   3m 20s,    9.6% completed, time steps left  651
#   Time to finish   3m 19s,    9.7% completed, time steps left  650
#   Time to finish   3m 18s,    9.9% completed, time steps left  649
#   Time to finish   3m 17s,   10.0% completed, time steps left  648
#   Time to finish   3m 15s,   10.1% completed, time steps left  647
#   Time to finish   3m 14s,   10.3% completed, time steps left  646
#   Time to finish   3m 13s,   10.4% completed, time steps left  645
#   Time to finish   3m 12s,   10.6% completed, time steps left  644
#   Time to finish   3m 11s,   10.7% completed, time steps left  643
#   Time to finish   3m 10s,   10.8% completed, time steps left  642
#   Time to finish   3m  9s,   11.0% completed, time steps left  641
#   Time to finish   3m  8s,   11.1% completed, time steps left  640
#   Time to finish   3m  7s,   11.2% completed, time steps left  639
#   Time to finish   3m  6s,   11.4% completed, time steps left  638
#   Time to finish   3m  5s,   11.5% completed, time steps left  637
#   Time to finish   3m  5s,   11.7% completed, time steps left  636
#   Time to finish   3m  4s,   11.8% completed, time steps left  635
#   Time to finish   3m  3s,   11.9% completed, time steps left  634
#   Time to finish   3m  2s,   12.1% completed, time steps left  633
#   Time to finish   3m  1s,   12.2% completed, time steps left  632
#   Time to finish   3m  0s,   12.4% completed, time steps left  631
#   Time to finish   2m 59s,   12.5% completed, time steps left  630
#   Time to finish   2m 59s,   12.6% completed, time steps left  629
#   Time to finish   2m 58s,   12.8% completed, time steps left  628
#   Time to finish   2m 57s,   12.9% completed, time steps left  627
#   Time to finish   2m 56s,   13.1% completed, time steps left  626
#   Time to finish   2m 56s,   13.2% completed, time steps left  625
#   Time to finish   2m 55s,   13.3% completed, time steps left  624
#   Time to finish   2m 54s,   13.5% completed, time steps left  623
#   Time to finish   2m 53s,   13.6% completed, time steps left  622
#   Time to finish   2m 53s,   13.8% completed, time steps left  621
#   Time to finish   2m 52s,   13.9% completed, time steps left  620
#   Time to finish   2m 51s,   14.0% completed, time steps left  619
#   Time to finish   2m 51s,   14.2% completed, time steps left  618
#   Time to finish   2m 50s,   14.3% completed, time steps left  617
#   Time to finish   2m 49s,   14.4% completed, time steps left  616
#   Time to finish   2m 49s,   14.6% completed, time steps left  615
#   Time to finish   2m 48s,   14.7% completed, time steps left  614
#   Time to finish   2m 47s,   14.9% completed, time steps left  613
#   Time to finish   2m 47s,   15.0% completed, time steps left  612
#   Time to finish   2m 46s,   15.1% completed, time steps left  611
#   Time to finish   2m 46s,   15.3% completed, time steps left  610
#   Time to finish   2m 45s,   15.4% completed, time steps left  609
#   Time to finish   2m 44s,   15.6% completed, time steps left  608
#   Time to finish   2m 44s,   15.7% completed, time steps left  607
#   Time to finish   2m 43s,   15.8% completed, time steps left  606
#   Time to finish   2m 43s,   16.0% completed, time steps left  605
#   Time to finish   2m 42s,   16.1% completed, time steps left  604
#   Time to finish   2m 41s,   16.2% completed, time steps left  603
#   Time to finish   2m 41s,   16.4% completed, time steps left  602
#   Time to finish   2m 40s,   16.5% completed, time steps left  601
#   Time to finish   2m 40s,   16.7% completed, time steps left  600
#   Time to finish   2m 57s,   16.8% completed, time steps left  599
#   Time to finish   2m 56s,   16.9% completed, time steps left  598
#   Time to finish   2m 56s,   17.1% completed, time steps left  597
#   Time to finish   2m 55s,   17.2% completed, time steps left  596
#   Time to finish   2m 54s,   17.4% completed, time steps left  595
#   Time to finish   2m 54s,   17.5% completed, time steps left  594
#   Time to finish   2m 53s,   17.6% completed, time steps left  593
#   Time to finish   2m 52s,   17.8% completed, time steps left  592
#   Time to finish   2m 51s,   17.9% completed, time steps left  591
#   Time to finish   2m 51s,   18.1% completed, time steps left  590
#   Time to finish   2m 50s,   18.2% completed, time steps left  589
#   Time to finish   2m 50s,   18.3% completed, time steps left  588
#   Time to finish   2m 49s,   18.5% completed, time steps left  587
#   Time to finish   2m 48s,   18.6% completed, time steps left  586
#   Time to finish   2m 48s,   18.8% completed, time steps left  585
#   Time to finish   2m 47s,   18.9% completed, time steps left  584
#   Time to finish   2m 46s,   19.0% completed, time steps left  583
#   Time to finish   2m 46s,   19.2% completed, time steps left  582
#   Time to finish   2m 45s,   19.3% completed, time steps left  581
#   Time to finish   2m 45s,   19.4% completed, time steps left  580
#   Time to finish   2m 44s,   19.6% completed, time steps left  579
#   Time to finish   2m 43s,   19.7% completed, time steps left  578
#   Time to finish   2m 43s,   19.9% completed, time steps left  577
#   Time to finish   2m 42s,   20.0% completed, time steps left  576
#   Time to finish   2m 42s,   20.1% completed, time steps left  575
#   Time to finish   2m 41s,   20.3% completed, time steps left  574
#   Time to finish   2m 41s,   20.4% completed, time steps left  573
#   Time to finish   2m 40s,   20.6% completed, time steps left  572
#   Time to finish   2m 40s,   20.7% completed, time steps left  571
#   Time to finish   2m 39s,   20.8% completed, time steps left  570
#   Time to finish   2m 38s,   21.0% completed, time steps left  569
#   Time to finish   2m 38s,   21.1% completed, time steps left  568
#   Time to finish   2m 37s,   21.2% completed, time steps left  567
#   Time to finish   2m 37s,   21.4% completed, time steps left  566
#   Time to finish   2m 36s,   21.5% completed, time steps left  565
#   Time to finish   2m 36s,   21.7% completed, time steps left  564
#   Time to finish   2m 35s,   21.8% completed, time steps left  563
#   Time to finish   2m 35s,   21.9% completed, time steps left  562
#   Time to finish   2m 34s,   22.1% completed, time steps left  561
#   Time to finish   2m 34s,   22.2% completed, time steps left  560
#   Time to finish   2m 33s,   22.4% completed, time steps left  559
#   Time to finish   2m 33s,   22.5% completed, time steps left  558
#   Time to finish   2m 32s,   22.6% completed, time steps left  557
#   Time to finish   2m 32s,   22.8% completed, time steps left  556
#   Time to finish   2m 31s,   22.9% completed, time steps left  555
#   Time to finish   2m 31s,   23.1% completed, time steps left  554
#   Time to finish   2m 30s,   23.2% completed, time steps left  553
#   Time to finish   2m 30s,   23.3% completed, time steps left  552
#   Time to finish   2m 29s,   23.5% completed, time steps left  551
#   Time to finish   2m 29s,   23.6% completed, time steps left  550
#   Time to finish   2m 28s,   23.8% completed, time steps left  549
#   Time to finish   2m 28s,   23.9% completed, time steps left  548
#   Time to finish   2m 28s,   24.0% completed, time steps left  547
#   Time to finish   2m 27s,   24.2% completed, time steps left  546
#   Time to finish   2m 27s,   24.3% completed, time steps left  545
#   Time to finish   2m 26s,   24.4% completed, time steps left  544
#   Time to finish   2m 26s,   24.6% completed, time steps left  543
#   Time to finish   2m 25s,   24.7% completed, time steps left  542
#   Time to finish   2m 25s,   24.9% completed, time steps left  541
#   Time to finish   2m 24s,   25.0% completed, time steps left  540
#   Time to finish   2m 34s,   25.1% completed, time steps left  539
#   Time to finish   2m 34s,   25.3% completed, time steps left  538
#   Time to finish   2m 33s,   25.4% completed, time steps left  537
#   Time to finish   2m 33s,   25.6% completed, time steps left  536
#   Time to finish   2m 32s,   25.7% completed, time steps left  535
#   Time to finish   2m 32s,   25.8% completed, time steps left  534
#   Time to finish   2m 31s,   26.0% completed, time steps left  533
#   Time to finish   2m 31s,   26.1% completed, time steps left  532
#   Time to finish   2m 30s,   26.2% completed, time steps left  531
#   Time to finish   2m 30s,   26.4% completed, time steps left  530
#   Time to finish   2m 29s,   26.5% completed, time steps left  529
#   Time to finish   2m 29s,   26.7% completed, time steps left  528
#   Time to finish   2m 28s,   26.8% completed, time steps left  527
#   Time to finish   2m 28s,   26.9% completed, time steps left  526
#   Time to finish   2m 28s,   27.1% completed, time steps left  525
#   Time to finish   2m 27s,   27.2% completed, time steps left  524
#   Time to finish   2m 27s,   27.4% completed, time steps left  523
#   Time to finish   2m 26s,   27.5% completed, time steps left  522
#   Time to finish   2m 26s,   27.6% completed, time steps left  521
#   Time to finish   2m 25s,   27.8% completed, time steps left  520
#   Time to finish   2m 25s,   27.9% completed, time steps left  519
#   Time to finish   2m 24s,   28.1% completed, time steps left  518
#   Time to finish   2m 24s,   28.2% completed, time steps left  517
#   Time to finish   2m 23s,   28.3% completed, time steps left  516
#   Time to finish   2m 23s,   28.5% completed, time steps left  515
#   Time to finish   2m 23s,   28.6% completed, time steps left  514
#   Time to finish   2m 22s,   28.7% completed, time steps left  513
#   Time to finish   2m 22s,   28.9% completed, time steps left  512
#   Time to finish   2m 21s,   29.0% completed, time steps left  511
#   Time to finish   2m 21s,   29.2% completed, time steps left  510
#   Time to finish   2m 20s,   29.3% completed, time steps left  509
#   Time to finish   2m 20s,   29.4% completed, time steps left  508
#   Time to finish   2m 19s,   29.6% completed, time steps left  507
#   Time to finish   2m 19s,   29.7% completed, time steps left  506
#   Time to finish   2m 19s,   29.9% completed, time steps left  505
#   Time to finish   2m 18s,   30.0% completed, time steps left  504
#   Time to finish   2m 18s,   30.1% completed, time steps left  503
#   Time to finish   2m 17s,   30.3% completed, time steps left  502
#   Time to finish   2m 17s,   30.4% completed, time steps left  501
#   Time to finish   2m 17s,   30.6% completed, time steps left  500
#   Time to finish   2m 16s,   30.7% completed, time steps left  499
#   Time to finish   2m 16s,   30.8% completed, time steps left  498
#   Time to finish   2m 15s,   31.0% completed, time steps left  497
#   Time to finish   2m 15s,   31.1% completed, time steps left  496
#   Time to finish   2m 14s,   31.2% completed, time steps left  495
#   Time to finish   2m 14s,   31.4% completed, time steps left  494
#   Time to finish   2m 14s,   31.5% completed, time steps left  493
#   Time to finish   2m 13s,   31.7% completed, time steps left  492
#   Time to finish   2m 13s,   31.8% completed, time steps left  491
#   Time to finish   2m 12s,   31.9% completed, time steps left  490
#   Time to finish   2m 12s,   32.1% completed, time steps left  489
#   Time to finish   2m 12s,   32.2% completed, time steps left  488
#   Time to finish   2m 11s,   32.4% completed, time steps left  487
#   Time to finish   2m 11s,   32.5% completed, time steps left  486
#   Time to finish   2m 11s,   32.6% completed, time steps left  485
#   Time to finish   2m 10s,   32.8% completed, time steps left  484
#   Time to finish   2m 10s,   32.9% completed, time steps left  483
#   Time to finish   2m  9s,   33.1% completed, time steps left  482
#   Time to finish   2m  9s,   33.2% completed, time steps left  481
#   Time to finish   2m  9s,   33.3% completed, time steps left  480
#   Time to finish   2m 15s,   33.5% completed, time steps left  479
#   Time to finish   2m 15s,   33.6% completed, time steps left  478
#   Time to finish   2m 14s,   33.8% completed, time steps left  477
#   Time to finish   2m 14s,   33.9% completed, time steps left  476
#   Time to finish   2m 14s,   34.0% completed, time steps left  475
#   Time to finish   2m 13s,   34.2% completed, time steps left  474
#   Time to finish   2m 13s,   34.3% completed, time steps left  473
#   Time to finish   2m 12s,   34.4% completed, time steps left  472
#   Time to finish   2m 12s,   34.6% completed, time steps left  471
#   Time to finish   2m 12s,   34.7% completed, time steps left  470
#   Time to finish   2m 11s,   34.9% completed, time steps left  469
#   Time to finish   2m 11s,   35.0% completed, time steps left  468
#   Time to finish   2m 10s,   35.1% completed, time steps left  467
#   Time to finish   2m 10s,   35.3% completed, time steps left  466
#   Time to finish   2m 10s,   35.4% completed, time steps left  465
#   Time to finish   2m  9s,   35.6% completed, time steps left  464
#   Time to finish   2m  9s,   35.7% completed, time steps left  463
#   Time to finish   2m  8s,   35.8% completed, time steps left  462
#   Time to finish   2m  8s,   36.0% completed, time steps left  461
#   Time to finish   2m  8s,   36.1% completed, time steps left  460
#   Time to finish   2m  7s,   36.2% completed, time steps left  459
#   Time to finish   2m  7s,   36.4% completed, time steps left  458
#   Time to finish   2m  6s,   36.5% completed, time steps left  457
#   Time to finish   2m  6s,   36.7% completed, time steps left  456
#   Time to finish   2m  6s,   36.8% completed, time steps left  455
#   Time to finish   2m  5s,   36.9% completed, time steps left  454
#   Time to finish   2m  5s,   37.1% completed, time steps left  453
#   Time to finish   2m  4s,   37.2% completed, time steps left  452
#   Time to finish   2m  4s,   37.4% completed, time steps left  451
#   Time to finish   2m  4s,   37.5% completed, time steps left  450
#   Time to finish   2m  3s,   37.6% completed, time steps left  449
#   Time to finish   2m  3s,   37.8% completed, time steps left  448
#   Time to finish   2m  3s,   37.9% completed, time steps left  447
#   Time to finish   2m  2s,   38.1% completed, time steps left  446
#   Time to finish   2m  2s,   38.2% completed, time steps left  445
#   Time to finish   2m  1s,   38.3% completed, time steps left  444
#   Time to finish   2m  1s,   38.5% completed, time steps left  443
#   Time to finish   2m  1s,   38.6% completed, time steps left  442
#   Time to finish   2m  0s,   38.8% completed, time steps left  441
#   Time to finish   2m  0s,   38.9% completed, time steps left  440
#   Time to finish   2m  0s,   39.0% completed, time steps left  439
#   Time to finish   1m 59s,   39.2% completed, time steps left  438
#   Time to finish   1m 59s,   39.3% completed, time steps left  437
#   Time to finish   1m 59s,   39.4% completed, time steps left  436
#   Time to finish   1m 58s,   39.6% completed, time steps left  435
#   Time to finish   1m 58s,   39.7% completed, time steps left  434
#   Time to finish   1m 57s,   39.9% completed, time steps left  433
#   Time to finish   1m 57s,   40.0% completed, time steps left  432
#   Time to finish   1m 57s,   40.1% completed, time steps left  431
#   Time to finish   1m 56s,   40.3% completed, time steps left  430
#   Time to finish   1m 56s,   40.4% completed, time steps left  429
#   Time to finish   1m 56s,   40.6% completed, time steps left  428
#   Time to finish   1m 55s,   40.7% completed, time steps left  427
#   Time to finish   1m 55s,   40.8% completed, time steps left  426
#   Time to finish   1m 55s,   41.0% completed, time steps left  425
#   Time to finish   1m 54s,   41.1% completed, time steps left  424
#   Time to finish   1m 54s,   41.2% completed, time steps left  423
#   Time to finish   1m 54s,   41.4% completed, time steps left  422
#   Time to finish   1m 53s,   41.5% completed, time steps left  421
#   Time to finish   1m 53s,   41.7% completed, time steps left  420
#   Time to finish   1m 57s,   41.8% completed, time steps left  419
#   Time to finish   1m 57s,   41.9% completed, time steps left  418
#   Time to finish   1m 57s,   42.1% completed, time steps left  417
#   Time to finish   1m 56s,   42.2% completed, time steps left  416
#   Time to finish   1m 56s,   42.4% completed, time steps left  415
#   Time to finish   1m 55s,   42.5% completed, time steps left  414
#   Time to finish   1m 55s,   42.6% completed, time steps left  413
#   Time to finish   1m 55s,   42.8% completed, time steps left  412
#   Time to finish   1m 54s,   42.9% completed, time steps left  411
#   Time to finish   1m 54s,   43.1% completed, time steps left  410
#   Time to finish   1m 54s,   43.2% completed, time steps left  409
#   Time to finish   1m 53s,   43.3% completed, time steps left  408
#   Time to finish   1m 53s,   43.5% completed, time steps left  407
#   Time to finish   1m 52s,   43.6% completed, time steps left  406
#   Time to finish   1m 52s,   43.8% completed, time steps left  405
#   Time to finish   1m 52s,   43.9% completed, time steps left  404
#   Time to finish   1m 51s,   44.0% completed, time steps left  403
#   Time to finish   1m 51s,   44.2% completed, time steps left  402
#   Time to finish   1m 51s,   44.3% completed, time steps left  401
#   Time to finish   1m 50s,   44.4% completed, time steps left  400
#   Time to finish   1m 50s,   44.6% completed, time steps left  399
#   Time to finish   1m 50s,   44.7% completed, time steps left  398
#   Time to finish   1m 49s,   44.9% completed, time steps left  397
#   Time to finish   1m 49s,   45.0% completed, time steps left  396
#   Time to finish   1m 49s,   45.1% completed, time steps left  395
#   Time to finish   1m 48s,   45.3% completed, time steps left  394
#   Time to finish   1m 48s,   45.4% completed, time steps left  393
#   Time to finish   1m 48s,   45.6% completed, time steps left  392
#   Time to finish   1m 47s,   45.7% completed, time steps left  391
#   Time to finish   1m 47s,   45.8% completed, time steps left  390
#   Time to finish   1m 46s,   46.0% completed, time steps left  389
#   Time to finish   1m 46s,   46.1% completed, time steps left  388
#   Time to finish   1m 46s,   46.2% completed, time steps left  387
#   Time to finish   1m 45s,   46.4% completed, time steps left  386
#   Time to finish   1m 45s,   46.5% completed, time steps left  385
#   Time to finish   1m 45s,   46.7% completed, time steps left  384
#   Time to finish   1m 44s,   46.8% completed, time steps left  383
#   Time to finish   1m 44s,   46.9% completed, time steps left  382
#   Time to finish   1m 44s,   47.1% completed, time steps left  381
#   Time to finish   1m 43s,   47.2% completed, time steps left  380
#   Time to finish   1m 43s,   47.4% completed, time steps left  379
#   Time to finish   1m 43s,   47.5% completed, time steps left  378
#   Time to finish   1m 42s,   47.6% completed, time steps left  377
#   Time to finish   1m 42s,   47.8% completed, time steps left  376
#   Time to finish   1m 42s,   47.9% completed, time steps left  375
#   Time to finish   1m 41s,   48.1% completed, time steps left  374
#   Time to finish   1m 41s,   48.2% completed, time steps left  373
#   Time to finish   1m 41s,   48.3% completed, time steps left  372
#   Time to finish   1m 40s,   48.5% completed, time steps left  371
#   Time to finish   1m 40s,   48.6% completed, time steps left  370
#   Time to finish   1m 40s,   48.8% completed, time steps left  369
#   Time to finish   1m 39s,   48.9% completed, time steps left  368
#   Time to finish   1m 39s,   49.0% completed, time steps left  367
#   Time to finish   1m 39s,   49.2% completed, time steps left  366
#   Time to finish   1m 38s,   49.3% completed, time steps left  365
#   Time to finish   1m 38s,   49.4% completed, time steps left  364
#   Time to finish   1m 38s,   49.6% completed, time steps left  363
#   Time to finish   1m 37s,   49.7% completed, time steps left  362
#   Time to finish   1m 37s,   49.9% completed, time steps left  361
#   Time to finish   1m 37s,   50.0% completed, time steps left  360
#   Time to finish   1m 40s,   50.1% completed, time steps left  359
#   Time to finish   1m 40s,   50.3% completed, time steps left  358
#   Time to finish   1m 39s,   50.4% completed, time steps left  357
#   Time to finish   1m 39s,   50.6% completed, time steps left  356
#   Time to finish   1m 39s,   50.7% completed, time steps left  355
#   Time to finish   1m 38s,   50.8% completed, time steps left  354
#   Time to finish   1m 38s,   51.0% completed, time steps left  353
#   Time to finish   1m 38s,   51.1% completed, time steps left  352
#   Time to finish   1m 37s,   51.2% completed, time steps left  351
#   Time to finish   1m 37s,   51.4% completed, time steps left  350
#   Time to finish   1m 37s,   51.5% completed, time steps left  349
#   Time to finish   1m 36s,   51.7% completed, time steps left  348
#   Time to finish   1m 36s,   51.8% completed, time steps left  347
#   Time to finish   1m 36s,   51.9% completed, time steps left  346
#   Time to finish   1m 35s,   52.1% completed, time steps left  345
#   Time to finish   1m 35s,   52.2% completed, time steps left  344
#   Time to finish   1m 35s,   52.4% completed, time steps left  343
#   Time to finish   1m 34s,   52.5% completed, time steps left  342
#   Time to finish   1m 34s,   52.6% completed, time steps left  341
#   Time to finish   1m 34s,   52.8% completed, time steps left  340
#   Time to finish   1m 33s,   52.9% completed, time steps left  339
#   Time to finish   1m 33s,   53.1% completed, time steps left  338
#   Time to finish   1m 33s,   53.2% completed, time steps left  337
#   Time to finish   1m 32s,   53.3% completed, time steps left  336
#   Time to finish   1m 32s,   53.5% completed, time steps left  335
#   Time to finish   1m 32s,   53.6% completed, time steps left  334
#   Time to finish   1m 31s,   53.8% completed, time steps left  333
#   Time to finish   1m 31s,   53.9% completed, time steps left  332
#   Time to finish   1m 31s,   54.0% completed, time steps left  331
#   Time to finish   1m 30s,   54.2% completed, time steps left  330
#   Time to finish   1m 30s,   54.3% completed, time steps left  329
#   Time to finish   1m 30s,   54.4% completed, time steps left  328
#   Time to finish   1m 29s,   54.6% completed, time steps left  327
#   Time to finish   1m 29s,   54.7% completed, time steps left  326
#   Time to finish   1m 29s,   54.9% completed, time steps left  325
#   Time to finish   1m 28s,   55.0% completed, time steps left  324
#   Time to finish   1m 28s,   55.1% completed, time steps left  323
#   Time to finish   1m 28s,   55.3% completed, time steps left  322
#   Time to finish   1m 27s,   55.4% completed, time steps left  321
#   Time to finish   1m 27s,   55.6% completed, time steps left  320
#   Time to finish   1m 27s,   55.7% completed, time steps left  319
#   Time to finish   1m 26s,   55.8% completed, time steps left  318
#   Time to finish   1m 26s,   56.0% completed, time steps left  317
#   Time to finish   1m 26s,   56.1% completed, time steps left  316
#   Time to finish   1m 25s,   56.2% completed, time steps left  315
#   Time to finish   1m 25s,   56.4% completed, time steps left  314
#   Time to finish   1m 25s,   56.5% completed, time steps left  313
#   Time to finish   1m 24s,   56.7% completed, time steps left  312
#   Time to finish   1m 24s,   56.8% completed, time steps left  311
#   Time to finish   1m 24s,   56.9% completed, time steps left  310
#   Time to finish   1m 24s,   57.1% completed, time steps left  309
#   Time to finish   1m 23s,   57.2% completed, time steps left  308
#   Time to finish   1m 23s,   57.4% completed, time steps left  307
#   Time to finish   1m 23s,   57.5% completed, time steps left  306
#   Time to finish   1m 22s,   57.6% completed, time steps left  305
#   Time to finish   1m 22s,   57.8% completed, time steps left  304
#   Time to finish   1m 22s,   57.9% completed, time steps left  303
#   Time to finish   1m 21s,   58.1% completed, time steps left  302
#   Time to finish   1m 21s,   58.2% completed, time steps left  301
#   Time to finish   1m 21s,   58.3% completed, time steps left  300
#   Time to finish   1m 23s,   58.5% completed, time steps left  299
#   Time to finish   1m 22s,   58.6% completed, time steps left  298
#   Time to finish   1m 22s,   58.8% completed, time steps left  297
#   Time to finish   1m 22s,   58.9% completed, time steps left  296
#   Time to finish   1m 21s,   59.0% completed, time steps left  295
#   Time to finish   1m 21s,   59.2% completed, time steps left  294
#   Time to finish   1m 21s,   59.3% completed, time steps left  293
#   Time to finish   1m 21s,   59.4% completed, time steps left  292
#   Time to finish   1m 20s,   59.6% completed, time steps left  291
#   Time to finish   1m 20s,   59.7% completed, time steps left  290
#   Time to finish   1m 20s,   59.9% completed, time steps left  289
#   Time to finish   1m 19s,   60.0% completed, time steps left  288
#   Time to finish   1m 19s,   60.1% completed, time steps left  287
#   Time to finish   1m 19s,   60.3% completed, time steps left  286
#   Time to finish   1m 18s,   60.4% completed, time steps left  285
#   Time to finish   1m 18s,   60.6% completed, time steps left  284
#   Time to finish   1m 18s,   60.7% completed, time steps left  283
#   Time to finish   1m 17s,   60.8% completed, time steps left  282
#   Time to finish   1m 17s,   61.0% completed, time steps left  281
#   Time to finish   1m 17s,   61.1% completed, time steps left  280
#   Time to finish   1m 16s,   61.3% completed, time steps left  279
#   Time to finish   1m 16s,   61.4% completed, time steps left  278
#   Time to finish   1m 16s,   61.5% completed, time steps left  277
#   Time to finish   1m 15s,   61.7% completed, time steps left  276
#   Time to finish   1m 15s,   61.8% completed, time steps left  275
#   Time to finish   1m 15s,   61.9% completed, time steps left  274
#   Time to finish   1m 15s,   62.1% completed, time steps left  273
#   Time to finish   1m 14s,   62.2% completed, time steps left  272
#   Time to finish   1m 14s,   62.4% completed, time steps left  271
#   Time to finish   1m 14s,   62.5% completed, time steps left  270
#   Time to finish   1m 13s,   62.6% completed, time steps left  269
#   Time to finish   1m 13s,   62.8% completed, time steps left  268
#   Time to finish   1m 13s,   62.9% completed, time steps left  267
#   Time to finish   1m 12s,   63.1% completed, time steps left  266
#   Time to finish   1m 12s,   63.2% completed, time steps left  265
#   Time to finish   1m 12s,   63.3% completed, time steps left  264
#   Time to finish   1m 11s,   63.5% completed, time steps left  263
#   Time to finish   1m 11s,   63.6% completed, time steps left  262
#   Time to finish   1m 11s,   63.7% completed, time steps left  261
#   Time to finish   1m 11s,   63.9% completed, time steps left  260
#   Time to finish   1m 10s,   64.0% completed, time steps left  259
#   Time to finish   1m 10s,   64.2% completed, time steps left  258
#   Time to finish   1m 10s,   64.3% completed, time steps left  257
#   Time to finish   1m  9s,   64.4% completed, time steps left  256
#   Time to finish   1m  9s,   64.6% completed, time steps left  255
#   Time to finish   1m  9s,   64.7% completed, time steps left  254
#   Time to finish   1m  8s,   64.9% completed, time steps left  253
#   Time to finish   1m  8s,   65.0% completed, time steps left  252
#   Time to finish   1m  8s,   65.1% completed, time steps left  251
#   Time to finish   1m  7s,   65.3% completed, time steps left  250
#   Time to finish   1m  7s,   65.4% completed, time steps left  249
#   Time to finish   1m  7s,   65.6% completed, time steps left  248
#   Time to finish   1m  7s,   65.7% completed, time steps left  247
#   Time to finish   1m  6s,   65.8% completed, time steps left  246
#   Time to finish   1m  6s,   66.0% completed, time steps left  245
#   Time to finish   1m  6s,   66.1% completed, time steps left  244
#   Time to finish   1m  5s,   66.2% completed, time steps left  243
#   Time to finish   1m  5s,   66.4% completed, time steps left  242
#   Time to finish   1m  5s,   66.5% completed, time steps left  241
#   Time to finish   1m  5s,   66.7% completed, time steps left  240
#   Time to finish   1m  6s,   66.8% completed, time steps left  239
#   Time to finish   1m  6s,   66.9% completed, time steps left  238
#   Time to finish   1m  5s,   67.1% completed, time steps left  237
#   Time to finish   1m  5s,   67.2% completed, time steps left  236
#   Time to finish   1m  5s,   67.4% completed, time steps left  235
#   Time to finish   1m  4s,   67.5% completed, time steps left  234
#   Time to finish   1m  4s,   67.6% completed, time steps left  233
#   Time to finish   1m  4s,   67.8% completed, time steps left  232
#   Time to finish   1m  3s,   67.9% completed, time steps left  231
#   Time to finish   1m  3s,   68.1% completed, time steps left  230
#   Time to finish   1m  3s,   68.2% completed, time steps left  229
#   Time to finish   1m  3s,   68.3% completed, time steps left  228
#   Time to finish   1m  2s,   68.5% completed, time steps left  227
#   Time to finish   1m  2s,   68.6% completed, time steps left  226
#   Time to finish   1m  2s,   68.8% completed, time steps left  225
#   Time to finish   1m  1s,   68.9% completed, time steps left  224
#   Time to finish   1m  1s,   69.0% completed, time steps left  223
#   Time to finish   1m  1s,   69.2% completed, time steps left  222
#   Time to finish  60s,   69.3% completed, time steps left  221
#   Time to finish  60s,   69.4% completed, time steps left  220
#   Time to finish  60s,   69.6% completed, time steps left  219
#   Time to finish  60s,   69.7% completed, time steps left  218
#   Time to finish  59s,   69.9% completed, time steps left  217
#   Time to finish  59s,   70.0% completed, time steps left  216
#   Time to finish  59s,   70.1% completed, time steps left  215
#   Time to finish  58s,   70.3% completed, time steps left  214
#   Time to finish  58s,   70.4% completed, time steps left  213
#   Time to finish  58s,   70.6% completed, time steps left  212
#   Time to finish  57s,   70.7% completed, time steps left  211
#   Time to finish  57s,   70.8% completed, time steps left  210
#   Time to finish  57s,   71.0% completed, time steps left  209
#   Time to finish  57s,   71.1% completed, time steps left  208
#   Time to finish  56s,   71.2% completed, time steps left  207
#   Time to finish  56s,   71.4% completed, time steps left  206
#   Time to finish  56s,   71.5% completed, time steps left  205
#   Time to finish  55s,   71.7% completed, time steps left  204
#   Time to finish  55s,   71.8% completed, time steps left  203
#   Time to finish  55s,   71.9% completed, time steps left  202
#   Time to finish  55s,   72.1% completed, time steps left  201
#   Time to finish  54s,   72.2% completed, time steps left  200
#   Time to finish  54s,   72.4% completed, time steps left  199
#   Time to finish  54s,   72.5% completed, time steps left  198
#   Time to finish  53s,   72.6% completed, time steps left  197
#   Time to finish  53s,   72.8% completed, time steps left  196
#   Time to finish  53s,   72.9% completed, time steps left  195
#   Time to finish  52s,   73.1% completed, time steps left  194
#   Time to finish  52s,   73.2% completed, time steps left  193
#   Time to finish  52s,   73.3% completed, time steps left  192
#   Time to finish  52s,   73.5% completed, time steps left  191
#   Time to finish  51s,   73.6% completed, time steps left  190
#   Time to finish  51s,   73.8% completed, time steps left  189
#   Time to finish  51s,   73.9% completed, time steps left  188
#   Time to finish  50s,   74.0% completed, time steps left  187
#   Time to finish  50s,   74.2% completed, time steps left  186
#   Time to finish  50s,   74.3% completed, time steps left  185
#   Time to finish  50s,   74.4% completed, time steps left  184
#   Time to finish  49s,   74.6% completed, time steps left  183
#   Time to finish  49s,   74.7% completed, time steps left  182
#   Time to finish  49s,   74.9% completed, time steps left  181
#   Time to finish  48s,   75.0% completed, time steps left  180
#   Time to finish  49s,   75.1% completed, time steps left  179
#   Time to finish  49s,   75.3% completed, time steps left  178
#   Time to finish  49s,   75.4% completed, time steps left  177
#   Time to finish  48s,   75.6% completed, time steps left  176
#   Time to finish  48s,   75.7% completed, time steps left  175
#   Time to finish  48s,   75.8% completed, time steps left  174
#   Time to finish  47s,   76.0% completed, time steps left  173
#   Time to finish  47s,   76.1% completed, time steps left  172
#   Time to finish  47s,   76.2% completed, time steps left  171
#   Time to finish  47s,   76.4% completed, time steps left  170
#   Time to finish  46s,   76.5% completed, time steps left  169
#   Time to finish  46s,   76.7% completed, time steps left  168
#   Time to finish  46s,   76.8% completed, time steps left  167
#   Time to finish  45s,   76.9% completed, time steps left  166
#   Time to finish  45s,   77.1% completed, time steps left  165
#   Time to finish  45s,   77.2% completed, time steps left  164
#   Time to finish  45s,   77.4% completed, time steps left  163
#   Time to finish  44s,   77.5% completed, time steps left  162
#   Time to finish  44s,   77.6% completed, time steps left  161
#   Time to finish  44s,   77.8% completed, time steps left  160
#   Time to finish  43s,   77.9% completed, time steps left  159
#   Time to finish  43s,   78.1% completed, time steps left  158
#   Time to finish  43s,   78.2% completed, time steps left  157
#   Time to finish  43s,   78.3% completed, time steps left  156
#   Time to finish  42s,   78.5% completed, time steps left  155
#   Time to finish  42s,   78.6% completed, time steps left  154
#   Time to finish  42s,   78.8% completed, time steps left  153
#   Time to finish  41s,   78.9% completed, time steps left  152
#   Time to finish  41s,   79.0% completed, time steps left  151
#   Time to finish  41s,   79.2% completed, time steps left  150
#   Time to finish  40s,   79.3% completed, time steps left  149
#   Time to finish  40s,   79.4% completed, time steps left  148
#   Time to finish  40s,   79.6% completed, time steps left  147
#   Time to finish  40s,   79.7% completed, time steps left  146
#   Time to finish  39s,   79.9% completed, time steps left  145
#   Time to finish  39s,   80.0% completed, time steps left  144
#   Time to finish  39s,   80.1% completed, time steps left  143
#   Time to finish  38s,   80.3% completed, time steps left  142
#   Time to finish  38s,   80.4% completed, time steps left  141
#   Time to finish  38s,   80.6% completed, time steps left  140
#   Time to finish  38s,   80.7% completed, time steps left  139
#   Time to finish  37s,   80.8% completed, time steps left  138
#   Time to finish  37s,   81.0% completed, time steps left  137
#   Time to finish  37s,   81.1% completed, time steps left  136
#   Time to finish  36s,   81.2% completed, time steps left  135
#   Time to finish  36s,   81.4% completed, time steps left  134
#   Time to finish  36s,   81.5% completed, time steps left  133
#   Time to finish  36s,   81.7% completed, time steps left  132
#   Time to finish  35s,   81.8% completed, time steps left  131
#   Time to finish  35s,   81.9% completed, time steps left  130
#   Time to finish  35s,   82.1% completed, time steps left  129
#   Time to finish  35s,   82.2% completed, time steps left  128
#   Time to finish  34s,   82.4% completed, time steps left  127
#   Time to finish  34s,   82.5% completed, time steps left  126
#   Time to finish  34s,   82.6% completed, time steps left  125
#   Time to finish  33s,   82.8% completed, time steps left  124
#   Time to finish  33s,   82.9% completed, time steps left  123
#   Time to finish  33s,   83.1% completed, time steps left  122
#   Time to finish  33s,   83.2% completed, time steps left  121
#   Time to finish  32s,   83.3% completed, time steps left  120
#   Time to finish  33s,   83.5% completed, time steps left  119
#   Time to finish  32s,   83.6% completed, time steps left  118
#   Time to finish  32s,   83.8% completed, time steps left  117
#   Time to finish  32s,   83.9% completed, time steps left  116
#   Time to finish  32s,   84.0% completed, time steps left  115
#   Time to finish  31s,   84.2% completed, time steps left  114
#   Time to finish  31s,   84.3% completed, time steps left  113
#   Time to finish  31s,   84.4% completed, time steps left  112
#   Time to finish  30s,   84.6% completed, time steps left  111
#   Time to finish  30s,   84.7% completed, time steps left  110
#   Time to finish  30s,   84.9% completed, time steps left  109
#   Time to finish  30s,   85.0% completed, time steps left  108
#   Time to finish  29s,   85.1% completed, time steps left  107
#   Time to finish  29s,   85.3% completed, time steps left  106
#   Time to finish  29s,   85.4% completed, time steps left  105
#   Time to finish  28s,   85.6% completed, time steps left  104
#   Time to finish  28s,   85.7% completed, time steps left  103
#   Time to finish  28s,   85.8% completed, time steps left  102
#   Time to finish  28s,   86.0% completed, time steps left  101
#   Time to finish  27s,   86.1% completed, time steps left  100
#   Time to finish  27s,   86.2% completed, time steps left  99
#   Time to finish  27s,   86.4% completed, time steps left  98
#   Time to finish  26s,   86.5% completed, time steps left  97
#   Time to finish  26s,   86.7% completed, time steps left  96
#   Time to finish  26s,   86.8% completed, time steps left  95
#   Time to finish  26s,   86.9% completed, time steps left  94
#   Time to finish  25s,   87.1% completed, time steps left  93
#   Time to finish  25s,   87.2% completed, time steps left  92
#   Time to finish  25s,   87.4% completed, time steps left  91
#   Time to finish  24s,   87.5% completed, time steps left  90
#   Time to finish  24s,   87.6% completed, time steps left  89
#   Time to finish  24s,   87.8% completed, time steps left  88
#   Time to finish  24s,   87.9% completed, time steps left  87
#   Time to finish  23s,   88.1% completed, time steps left  86
#   Time to finish  23s,   88.2% completed, time steps left  85
#   Time to finish  23s,   88.3% completed, time steps left  84
#   Time to finish  22s,   88.5% completed, time steps left  83
#   Time to finish  22s,   88.6% completed, time steps left  82
#   Time to finish  22s,   88.8% completed, time steps left  81
#   Time to finish  22s,   88.9% completed, time steps left  80
#   Time to finish  21s,   89.0% completed, time steps left  79
#   Time to finish  21s,   89.2% completed, time steps left  78
#   Time to finish  21s,   89.3% completed, time steps left  77
#   Time to finish  21s,   89.4% completed, time steps left  76
#   Time to finish  20s,   89.6% completed, time steps left  75
#   Time to finish  20s,   89.7% completed, time steps left  74
#   Time to finish  20s,   89.9% completed, time steps left  73
#   Time to finish  19s,   90.0% completed, time steps left  72
#   Time to finish  19s,   90.1% completed, time steps left  71
#   Time to finish  19s,   90.3% completed, time steps left  70
#   Time to finish  19s,   90.4% completed, time steps left  69
#   Time to finish  18s,   90.6% completed, time steps left  68
#   Time to finish  18s,   90.7% completed, time steps left  67
#   Time to finish  18s,   90.8% completed, time steps left  66
#   Time to finish  18s,   91.0% completed, time steps left  65
#   Time to finish  17s,   91.1% completed, time steps left  64
#   Time to finish  17s,   91.2% completed, time steps left  63
#   Time to finish  17s,   91.4% completed, time steps left  62
#   Time to finish  16s,   91.5% completed, time steps left  61
#   Time to finish  16s,   91.7% completed, time steps left  60
#   Time to finish  16s,   91.8% completed, time steps left  59
#   Time to finish  16s,   91.9% completed, time steps left  58
#   Time to finish  16s,   92.1% completed, time steps left  57
#   Time to finish  15s,   92.2% completed, time steps left  56
#   Time to finish  15s,   92.4% completed, time steps left  55
#   Time to finish  15s,   92.5% completed, time steps left  54
#   Time to finish  14s,   92.6% completed, time steps left  53
#   Time to finish  14s,   92.8% completed, time steps left  52
#   Time to finish  14s,   92.9% completed, time steps left  51
#   Time to finish  14s,   93.1% completed, time steps left  50
#   Time to finish  13s,   93.2% completed, time steps left  49
#   Time to finish  13s,   93.3% completed, time steps left  48
#   Time to finish  13s,   93.5% completed, time steps left  47
#   Time to finish  13s,   93.6% completed, time steps left  46
#   Time to finish  12s,   93.8% completed, time steps left  45
#   Time to finish  12s,   93.9% completed, time steps left  44
#   Time to finish  12s,   94.0% completed, time steps left  43
#   Time to finish  11s,   94.2% completed, time steps left  42
#   Time to finish  11s,   94.3% completed, time steps left  41
#   Time to finish  11s,   94.4% completed, time steps left  40
#   Time to finish  11s,   94.6% completed, time steps left  39
#   Time to finish  10s,   94.7% completed, time steps left  38
#   Time to finish  10s,   94.9% completed, time steps left  37
#   Time to finish  10s,   95.0% completed, time steps left  36
#   Time to finish  10s,   95.1% completed, time steps left  35
#   Time to finish   9s,   95.3% completed, time steps left  34
#   Time to finish   9s,   95.4% completed, time steps left  33
#   Time to finish   9s,   95.6% completed, time steps left  32
#   Time to finish   8s,   95.7% completed, time steps left  31
#   Time to finish   8s,   95.8% completed, time steps left  30
#   Time to finish   8s,   96.0% completed, time steps left  29
#   Time to finish   8s,   96.1% completed, time steps left  28
#   Time to finish   7s,   96.2% completed, time steps left  27
#   Time to finish   7s,   96.4% completed, time steps left  26
#   Time to finish   7s,   96.5% completed, time steps left  25
#   Time to finish   6s,   96.7% completed, time steps left  24
#   Time to finish   6s,   96.8% completed, time steps left  23
#   Time to finish   6s,   96.9% completed, time steps left  22
#   Time to finish   6s,   97.1% completed, time steps left  21
#   Time to finish   5s,   97.2% completed, time steps left  20
#   Time to finish   5s,   97.4% completed, time steps left  19
#   Time to finish   5s,   97.5% completed, time steps left  18
#   Time to finish   5s,   97.6% completed, time steps left  17
#   Time to finish   4s,   97.8% completed, time steps left  16
# ...
#   Time to finish  54s,   72.1% completed, time steps left  201
#   Time to finish  53s,   72.2% completed, time steps left  200
#   Time to finish  53s,   72.4% completed, time steps left  199
#   Time to finish  53s,   72.5% completed, time steps left  198
#   Time to finish  52s,   72.6% completed, time steps left  197
#   Time to finish  52s,   72.8% completed, time steps left  196
#   Time to finish  52s,   72.9% completed, time steps left  195
#   Time to finish  52s,   73.1% completed, time steps left  194
#   Time to finish  51s,   73.2% completed, time steps left  193
#   Time to finish  51s,   73.3% completed, time steps left  192
#   Time to finish  51s,   73.5% completed, time steps left  191
#   Time to finish  50s,   73.6% completed, time steps left  190
#   Time to finish  50s,   73.8% completed, time steps left  189
#   Time to finish  50s,   73.9% completed, time steps left  188
#   Time to finish  50s,   74.0% completed, time steps left  187
#   Time to finish  49s,   74.2% completed, time steps left  186
#   Time to finish  49s,   74.3% completed, time steps left  185
#   Time to finish  49s,   74.4% completed, time steps left  184
#   Time to finish  48s,   74.6% completed, time steps left  183
#   Time to finish  48s,   74.7% completed, time steps left  182
#   Time to finish  48s,   74.9% completed, time steps left  181
#   Time to finish  48s,   75.0% completed, time steps left  180
#   Time to finish  48s,   75.1% completed, time steps left  179
#   Time to finish  48s,   75.3% completed, time steps left  178
#   Time to finish  48s,   75.4% completed, time steps left  177
#   Time to finish  48s,   75.6% completed, time steps left  176
#   Time to finish  47s,   75.7% completed, time steps left  175
#   Time to finish  47s,   75.8% completed, time steps left  174
#   Time to finish  47s,   76.0% completed, time steps left  173
#   Time to finish  46s,   76.1% completed, time steps left  172
#   Time to finish  46s,   76.2% completed, time steps left  171
#   Time to finish  46s,   76.4% completed, time steps left  170
#   Time to finish  46s,   76.5% completed, time steps left  169
#   Time to finish  45s,   76.7% completed, time steps left  168
#   Time to finish  45s,   76.8% completed, time steps left  167
#   Time to finish  45s,   76.9% completed, time steps left  166
#   Time to finish  44s,   77.1% completed, time steps left  165
#   Time to finish  44s,   77.2% completed, time steps left  164
#   Time to finish  44s,   77.4% completed, time steps left  163
#   Time to finish  44s,   77.5% completed, time steps left  162
#   Time to finish  43s,   77.6% completed, time steps left  161
#   Time to finish  43s,   77.8% completed, time steps left  160
#   Time to finish  43s,   77.9% completed, time steps left  159
#   Time to finish  42s,   78.1% completed, time steps left  158
#   Time to finish  42s,   78.2% completed, time steps left  157
#   Time to finish  42s,   78.3% completed, time steps left  156
#   Time to finish  42s,   78.5% completed, time steps left  155
#   Time to finish  41s,   78.6% completed, time steps left  154
#   Time to finish  41s,   78.8% completed, time steps left  153
#   Time to finish  41s,   78.9% completed, time steps left  152
#   Time to finish  40s,   79.0% completed, time steps left  151
#   Time to finish  40s,   79.2% completed, time steps left  150
#   Time to finish  40s,   79.3% completed, time steps left  149
#   Time to finish  40s,   79.4% completed, time steps left  148
#   Time to finish  39s,   79.6% completed, time steps left  147
#   Time to finish  39s,   79.7% completed, time steps left  146
#   Time to finish  39s,   79.9% completed, time steps left  145
#   Time to finish  38s,   80.0% completed, time steps left  144
#   Time to finish  38s,   80.1% completed, time steps left  143
#   Time to finish  38s,   80.3% completed, time steps left  142
#   Time to finish  38s,   80.4% completed, time steps left  141
#   Time to finish  37s,   80.6% completed, time steps left  140
#   Time to finish  37s,   80.7% completed, time steps left  139
#   Time to finish  37s,   80.8% completed, time steps left  138
#   Time to finish  36s,   81.0% completed, time steps left  137
#   Time to finish  36s,   81.1% completed, time steps left  136
#   Time to finish  36s,   81.2% completed, time steps left  135
#   Time to finish  36s,   81.4% completed, time steps left  134
#   Time to finish  35s,   81.5% completed, time steps left  133
#   Time to finish  35s,   81.7% completed, time steps left  132
#   Time to finish  35s,   81.8% completed, time steps left  131
#   Time to finish  35s,   81.9% completed, time steps left  130
#   Time to finish  34s,   82.1% completed, time steps left  129
#   Time to finish  34s,   82.2% completed, time steps left  128
#   Time to finish  34s,   82.4% completed, time steps left  127
#   Time to finish  33s,   82.5% completed, time steps left  126
#   Time to finish  33s,   82.6% completed, time steps left  125
#   Time to finish  33s,   82.8% completed, time steps left  124
#   Time to finish  33s,   82.9% completed, time steps left  123
#   Time to finish  32s,   83.1% completed, time steps left  122
#   Time to finish  32s,   83.2% completed, time steps left  121
#   Time to finish  32s,   83.3% completed, time steps left  120
#   Time to finish  32s,   83.5% completed, time steps left  119
#   Time to finish  32s,   83.6% completed, time steps left  118
#   Time to finish  32s,   83.8% completed, time steps left  117
#   Time to finish  31s,   83.9% completed, time steps left  116
#   Time to finish  31s,   84.0% completed, time steps left  115
#   Time to finish  31s,   84.2% completed, time steps left  114
#   Time to finish  30s,   84.3% completed, time steps left  113
#   Time to finish  30s,   84.4% completed, time steps left  112
#   Time to finish  30s,   84.6% completed, time steps left  111
#   Time to finish  30s,   84.7% completed, time steps left  110
#   Time to finish  29s,   84.9% completed, time steps left  109
#   Time to finish  29s,   85.0% completed, time steps left  108
#   Time to finish  29s,   85.1% completed, time steps left  107
#   Time to finish  29s,   85.3% completed, time steps left  106
#   Time to finish  28s,   85.4% completed, time steps left  105
#   Time to finish  28s,   85.6% completed, time steps left  104
#   Time to finish  28s,   85.7% completed, time steps left  103
#   Time to finish  27s,   85.8% completed, time steps left  102
#   Time to finish  27s,   86.0% completed, time steps left  101
#   Time to finish  27s,   86.1% completed, time steps left  100
#   Time to finish  27s,   86.2% completed, time steps left  99
#   Time to finish  26s,   86.4% completed, time steps left  98
#   Time to finish  26s,   86.5% completed, time steps left  97
#   Time to finish  26s,   86.7% completed, time steps left  96
#   Time to finish  25s,   86.8% completed, time steps left  95
#   Time to finish  25s,   86.9% completed, time steps left  94
#   Time to finish  25s,   87.1% completed, time steps left  93
#   Time to finish  25s,   87.2% completed, time steps left  92
#   Time to finish  24s,   87.4% completed, time steps left  91
#   Time to finish  24s,   87.5% completed, time steps left  90
#   Time to finish  24s,   87.6% completed, time steps left  89
#   Time to finish  24s,   87.8% completed, time steps left  88
#   Time to finish  23s,   87.9% completed, time steps left  87
#   Time to finish  23s,   88.1% completed, time steps left  86
#   Time to finish  23s,   88.2% completed, time steps left  85
#   Time to finish  22s,   88.3% completed, time steps left  84
#   Time to finish  22s,   88.5% completed, time steps left  83
#   Time to finish  22s,   88.6% completed, time steps left  82
#   Time to finish  22s,   88.8% completed, time steps left  81
#   Time to finish  21s,   88.9% completed, time steps left  80
#   Time to finish  21s,   89.0% completed, time steps left  79
#   Time to finish  21s,   89.2% completed, time steps left  78
#   Time to finish  21s,   89.3% completed, time steps left  77
#   Time to finish  20s,   89.4% completed, time steps left  76
#   Time to finish  20s,   89.6% completed, time steps left  75
#   Time to finish  20s,   89.7% completed, time steps left  74
#   Time to finish  19s,   89.9% completed, time steps left  73
#   Time to finish  19s,   90.0% completed, time steps left  72
#   Time to finish  19s,   90.1% completed, time steps left  71
#   Time to finish  19s,   90.3% completed, time steps left  70
#   Time to finish  18s,   90.4% completed, time steps left  69
#   Time to finish  18s,   90.6% completed, time steps left  68
#   Time to finish  18s,   90.7% completed, time steps left  67
#   Time to finish  18s,   90.8% completed, time steps left  66
#   Time to finish  17s,   91.0% completed, time steps left  65
#   Time to finish  17s,   91.1% completed, time steps left  64
#   Time to finish  17s,   91.2% completed, time steps left  63
#   Time to finish  16s,   91.4% completed, time steps left  62
#   Time to finish  16s,   91.5% completed, time steps left  61
#   Time to finish  16s,   91.7% completed, time steps left  60
#   Time to finish  16s,   91.8% completed, time steps left  59
#   Time to finish  16s,   91.9% completed, time steps left  58
#   Time to finish  15s,   92.1% completed, time steps left  57
#   Time to finish  15s,   92.2% completed, time steps left  56
#   Time to finish  15s,   92.4% completed, time steps left  55
#   Time to finish  15s,   92.5% completed, time steps left  54
#   Time to finish  14s,   92.6% completed, time steps left  53
#   Time to finish  14s,   92.8% completed, time steps left  52
#   Time to finish  14s,   92.9% completed, time steps left  51
#   Time to finish  13s,   93.1% completed, time steps left  50
#   Time to finish  13s,   93.2% completed, time steps left  49
#   Time to finish  13s,   93.3% completed, time steps left  48
#   Time to finish  13s,   93.5% completed, time steps left  47
#   Time to finish  12s,   93.6% completed, time steps left  46
#   Time to finish  12s,   93.8% completed, time steps left  45
#   Time to finish  12s,   93.9% completed, time steps left  44
#   Time to finish  12s,   94.0% completed, time steps left  43
#   Time to finish  11s,   94.2% completed, time steps left  42
#   Time to finish  11s,   94.3% completed, time steps left  41
#   Time to finish  11s,   94.4% completed, time steps left  40
#   Time to finish  10s,   94.6% completed, time steps left  39
#   Time to finish  10s,   94.7% completed, time steps left  38
#   Time to finish  10s,   94.9% completed, time steps left  37
#   Time to finish  10s,   95.0% completed, time steps left  36
#   Time to finish   9s,   95.1% completed, time steps left  35
#   Time to finish   9s,   95.3% completed, time steps left  34
#   Time to finish   9s,   95.4% completed, time steps left  33
#   Time to finish   9s,   95.6% completed, time steps left  32
#   Time to finish   8s,   95.7% completed, time steps left  31
#   Time to finish   8s,   95.8% completed, time steps left  30
#   Time to finish   8s,   96.0% completed, time steps left  29
#   Time to finish   7s,   96.1% completed, time steps left  28
#   Time to finish   7s,   96.2% completed, time steps left  27
#   Time to finish   7s,   96.4% completed, time steps left  26
#   Time to finish   7s,   96.5% completed, time steps left  25
#   Time to finish   6s,   96.7% completed, time steps left  24
#   Time to finish   6s,   96.8% completed, time steps left  23
#   Time to finish   6s,   96.9% completed, time steps left  22
#   Time to finish   6s,   97.1% completed, time steps left  21
#   Time to finish   5s,   97.2% completed, time steps left  20
#   Time to finish   5s,   97.4% completed, time steps left  19
#   Time to finish   5s,   97.5% completed, time steps left  18
#   Time to finish   5s,   97.6% completed, time steps left  17
#   Time to finish   4s,   97.8% completed, time steps left  16
#   Time to finish   4s,   97.9% completed, time steps left  15
#   Time to finish   4s,   98.1% completed, time steps left  14
#   Time to finish   3s,   98.2% completed, time steps left  13
#   Time to finish   3s,   98.3% completed, time steps left  12
#   Time to finish   3s,   98.5% completed, time steps left  11
#   Time to finish   3s,   98.6% completed, time steps left  10
#   Time to finish   2s,   98.8% completed, time steps left  9
#   Time to finish   2s,   98.9% completed, time steps left  8
#   Time to finish   2s,   99.0% completed, time steps left  7
#   Time to finish   2s,   99.2% completed, time steps left  6
#   Time to finish   1s,   99.3% completed, time steps left  5
#   Time to finish   1s,   99.4% completed, time steps left  4
#   Time to finish   1s,   99.6% completed, time steps left  3
#   Time to finish   1s,   99.7% completed, time steps left  2
#   Time to finish   0s,   99.9% completed, time steps left  1
#
# ------------------------------------------------------------------------------
#   FINISHED    Delft3D-FLOW
#               runid      : test
#               date, time : 2017-06-23, 09:01:09
# SUMMARY FOR PARTITION :  1
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  2
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  3
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  4
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  5
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  6
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  7
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  8
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  9
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION : 10
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain test
# ------------------------------------------------------------------------------
# D_Hydro [1498208469.825087] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.825299] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.825384] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.825558] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.825672] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.826242] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.826453] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.826652] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.826698] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1498208469.827107] <anonymous> >> d_hydro shutting down normally
