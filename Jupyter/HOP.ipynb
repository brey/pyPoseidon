# %%
# Tropical Cyclone tracking

# %% [markdown]
# Note: The translational velocity should (could) also be removed from the ECMWF data.

# %%
from notebook import *
from ipywidgets import *

# %%
from viewtrack import viewtrack4
from choose import choose
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ef74316e4833> in <module>()
# ----> 1 from viewtrack import viewtrack4
#       2 from choose import choose
#
# ImportError: No module named viewtrack

# %%
# %matplotlib notebook

# %%
from tc import tct
tctimes,tcnames=tct()

# %%
w=interact(choose,name=tcnames)
# Out:
# ['2016-05-19 12:00:00',
#  '2016-05-20 00:00:00',
#  '2016-05-20 12:00:00',
#  '2016-05-21 00:00:00',
#  '2016-05-21 12:00:00']

# %%
interact_manual(viewtrack4,tin=w.widget.result,stormname=w.widget.kwargs['name'])

# %%
interact(viewtrack4,tin='2016-05-19 12:00:00',stormname='ROANU')
# Out:
# 2015-09-29 00:00:00
# <function viewtrack.viewtrack4>
