# %% [markdown]
# ## Re-forcasting example

# %%
#to use the full width of the browser window
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
from pyPoseidon.utils.cast import *
from pyPoseidon.utils.data import *
# Out:
# WARNING: param.Version now supports PEP440 and a new tag based workflow. See param/version.py for more details

# %% [markdown]
# ### setup

# %%
#read the info from the first run
with open('/Users/brey/Downloads/EUR/20100201.00/eur025_info.pkl', 'r') as f:
              info=pickle.load(f)

# %%
#info

# %%
#define some info
info.update({'path':'/Users/brey/Downloads/EUR/', # The path of the project
     'case':'European 2010', # a reference tag
     })

# %%
#creating a time sequence of the runs
start_date = pd.to_datetime('2010-2-1 0:0:0')
end_date = pd.to_datetime('2010-2-2 12:0:0')
date_list = pd.date_range(start_date,end_date, freq='12H')
date_list
# Out:
# DatetimeIndex(['2010-02-01 00:00:00', '2010-02-01 12:00:00',
#                '2010-02-02 00:00:00', '2010-02-02 12:00:00'],
#               dtype='datetime64[ns]', freq='12H')

# %%
#append to dic
info.update({'start_date':start_date,'end_date':end_date, 'dates' : date_list})

# %%
#creating a sequence of folder to store the runs. In this case we name them after the date attribute.
#NOTE that the first folder is the fisrt run already perfomed!!
folders = [datetime.datetime.strftime(x, '%Y%m%d.%H') for x in date_list]
info.update({'folders':folders})
folders
# Out:
# ['20100201.00', '20100201.12', '20100202.00', '20100202.12']

# %%
#creating a sequence of folder from which we read the meteo.
meteo = []
PATH='/Users/brey/Downloads/'
for date in date_list:
    end_date= pd.to_datetime(date) + pd.to_timedelta(info['time_frame'])
    end_date = end_date.strftime(format='%Y-%m-%d %H:%M:%S')
    dr = pd.date_range(date, end_date, freq='73H')
    dur = [PATH+'{:04d}/{:02d}/{:02d}/'.format(x.year,x.month,x.day)+datetime.datetime.strftime(x, '%Y%m%d.%H')+'.tropical_cyclone.grib' for x in dr]
    meteo.append(dur)

# %%
meteo
# Out:
# [['/Users/brey/Downloads/2010/02/01/20100201.00.tropical_cyclone.grib'],
#  ['/Users/brey/Downloads/2010/02/01/20100201.12.tropical_cyclone.grib'],
#  ['/Users/brey/Downloads/2010/02/02/20100202.00.tropical_cyclone.grib'],
#  ['/Users/brey/Downloads/2010/02/02/20100202.12.tropical_cyclone.grib']]

# %%
info.update({'meteo_files':meteo})

# %%
#check
info['folders'],info['meteo_files']
# Out:
# (['20100201.00', '20100201.12', '20100202.00', '20100202.12'],
#  [['/Users/brey/Downloads/2010/02/01/20100201.00.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/01/20100201.12.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/02/20100202.00.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/02/20100202.12.tropical_cyclone.grib']])

# %%
#check dict
info
# Out:
# {'Dt': 1.0,
#  'atm': True,
#  'case': 'European 2010',
#  'conda_env': 'mpi3',
#  'date': Timestamp('2010-02-01 00:00:00'),
#  'dates': DatetimeIndex(['2010-02-01 00:00:00', '2010-02-01 12:00:00',
#                 '2010-02-02 00:00:00', '2010-02-02 12:00:00'],
#                dtype='datetime64[ns]', freq='12H'),
#  'dem': 'gebco',
#  'dft': 1,
#  'dpath': '/Users/brey/DATA/GEBCO_2014_2D.nc',
#  'end_date': Timestamp('2010-02-02 12:00:00'),
#  'epath': '/Users/brey/DELFT3D/SVN/7545/bin/lnx64/',
#  'folders': ['20100201.00', '20100201.12', '20100202.00', '20100202.12'],
#  'ft1': 0,
#  'ft2': 72,
#  'maxlat': 76.5,
#  'maxlon': 42.0,
#  'meteo': 'ecmwf_oper',
#  'meteo_files': [['/Users/brey/Downloads/2010/02/01/20100201.00.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/01/20100201.12.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/02/20100202.00.tropical_cyclone.grib'],
#   ['/Users/brey/Downloads/2010/02/02/20100202.12.tropical_cyclone.grib']],
#  'minlat': 25.05,
#  'minlon': -35.0,
#  'mpaths': ['/Users/brey/Downloads/2010/02/01/20100201.00.tropical_cyclone.grib'],
#  'ncores': 4,
#  'path': '/Users/brey/Downloads/EUR/',
#  'resolution': 0.25,
#  'rpath': '/Users/brey/Downloads/EUR/20100201.00/',
#  'rstep': 720,
#  'solver': 'd3d',
#  'start_date': Timestamp('2010-02-01 00:00:00'),
#  'step': 60,
#  'tag': 'eur025',
#  'tide': False,
#  'time_frame': '72H',
#  'update': ['meteo']}

# %% [markdown]
# ### run the hindcast

# %%
#set cast
h = cast(**info) # initialize

# %%
#info

# %%
h.run()
# Out:
# Restart link present
# overwriting
# process meteo
#
# extracting meteo from /Users/brey/Downloads/2010/02/01/20100201.12.tropical_cyclone.grib
#
# retrieving msl at 2010-02-01 12:00:00
#
# retrieving 10u at 2010-02-01 12:00:00
#
# retrieving 10v at 2010-02-01 12:00:00
#
# retrieving msl at 2010-02-01 15:00:00
#
# retrieving 10u at 2010-02-01 15:00:00
#
# retrieving 10v at 2010-02-01 15:00:00
#
# retrieving msl at 2010-02-01 18:00:00
#
# retrieving 10u at 2010-02-01 18:00:00
#
# retrieving 10v at 2010-02-01 18:00:00
#
# retrieving msl at 2010-02-01 21:00:00
#
# retrieving 10u at 2010-02-01 21:00:00
#
# retrieving 10v at 2010-02-01 21:00:00
#
# retrieving msl at 2010-02-02 00:00:00
#
# retrieving 10u at 2010-02-02 00:00:00
#
# retrieving 10v at 2010-02-02 00:00:00
#
# retrieving msl at 2010-02-02 03:00:00
#
# retrieving 10u at 2010-02-02 03:00:00
#
# retrieving 10v at 2010-02-02 03:00:00
#
# retrieving msl at 2010-02-02 06:00:00
#
# retrieving 10u at 2010-02-02 06:00:00
#
# retrieving 10v at 2010-02-02 06:00:00
#
# retrieving msl at 2010-02-02 09:00:00
#
# retrieving 10u at 2010-02-02 09:00:00
#
# retrieving 10v at 2010-02-02 09:00:00
#
# retrieving msl at 2010-02-02 12:00:00
#
# retrieving 10u at 2010-02-02 12:00:00
#
# retrieving 10v at 2010-02-02 12:00:00
#
# retrieving msl at 2010-02-02 15:00:00
#
# retrieving 10u at 2010-02-02 15:00:00
#
# retrieving 10v at 2010-02-02 15:00:00
#
# retrieving msl at 2010-02-02 18:00:00
#
# retrieving 10u at 2010-02-02 18:00:00
#
# retrieving 10v at 2010-02-02 18:00:00
#
# retrieving msl at 2010-02-02 21:00:00
#
# retrieving 10u at 2010-02-02 21:00:00
#
# retrieving 10v at 2010-02-02 21:00:00
#
# retrieving msl at 2010-02-03 00:00:00
#
# retrieving 10u at 2010-02-03 00:00:00
#
# retrieving 10v at 2010-02-03 00:00:00
#
# retrieving msl at 2010-02-03 03:00:00
#
# retrieving 10u at 2010-02-03 03:00:00
#
# retrieving 10v at 2010-02-03 03:00:00
#
# retrieving msl at 2010-02-03 06:00:00
#
# retrieving 10u at 2010-02-03 06:00:00
#
# retrieving 10v at 2010-02-03 06:00:00
#
# retrieving msl at 2010-02-03 09:00:00
#
# retrieving 10u at 2010-02-03 09:00:00
#
# retrieving 10v at 2010-02-03 09:00:00
#
# retrieving msl at 2010-02-03 12:00:00
#
# retrieving 10u at 2010-02-03 12:00:00
#
# retrieving 10v at 2010-02-03 12:00:00
#
# retrieving msl at 2010-02-03 15:00:00
#
# retrieving 10u at 2010-02-03 15:00:00
#
# retrieving 10v at 2010-02-03 15:00:00
#
# retrieving msl at 2010-02-03 18:00:00
#
# retrieving 10u at 2010-02-03 18:00:00
#
# retrieving 10v at 2010-02-03 18:00:00
#
# retrieving msl at 2010-02-03 21:00:00
#
# retrieving 10u at 2010-02-03 21:00:00
#
# retrieving 10v at 2010-02-03 21:00:00
#
# retrieving msl at 2010-02-04 00:00:00
#
# retrieving 10u at 2010-02-04 00:00:00
#
# retrieving 10v at 2010-02-04 00:00:00
#
# retrieving msl at 2010-02-04 03:00:00
#
# retrieving 10u at 2010-02-04 03:00:00
#
# retrieving 10v at 2010-02-04 03:00:00
#
# retrieving msl at 2010-02-04 06:00:00
#
# retrieving 10u at 2010-02-04 06:00:00
#
# retrieving 10v at 2010-02-04 06:00:00
#
# retrieving msl at 2010-02-04 09:00:00
#
# retrieving 10u at 2010-02-04 09:00:00
#
# retrieving 10v at 2010-02-04 09:00:00
#
# retrieving msl at 2010-02-04 12:00:00
#
# retrieving 10u at 2010-02-04 12:00:00
#
# retrieving 10v at 2010-02-04 12:00:00
# end of file /Users/brey/Downloads/2010/02/01/20100201.12.tropical_cyclone.grib
#
# meteo done
# executing
# MPI process number 001 has host unknown and is running on processor dmapcgf.isferea.project
# MPI process number 002 has host unknown and is running on processor dmapcgf.isferea.project
# MPI process number 003 has host unknown and is running on processor dmapcgf.isferea.project
# MPI process number 000 has host unknown and is running on processor dmapcgf.isferea.project
# --------------------------------------------------------------------------------
#        Deltares, FLOW2D3D Version 6.02.13.8578, Apr 16 2018, 11:35:48
#        libflow2d3d.so entry Flow2D3D::Run
# --------------------------------------------------------------------------------
#
# Part I    - Initialisation Time Dep. Data module...
#             runid : eur025
# Part II   - Creating intermediate files...
# Part III  - Initialisation of the Execution module...
# Part IV   - Reading complete MD-file...
# Part V    - Initialisation & checking input...
# Part VI   - Initialisation & checking second part...
# Part VII  - Initialisation output...
# Part VIII - Start Simulation...
#
#   Time to finish   0s,    0.0% completed, time steps left  4320
#   Time to finish   4m  4s,    0.0% completed, time steps left  4319
#   Time to finish   3m 19s,    0.0% completed, time steps left  4318
#   Time to finish   2m 59s,    0.1% completed, time steps left  4317
#   Time to finish   2m 53s,    0.1% completed, time steps left  4316
#   Time to finish   2m 49s,    0.1% completed, time steps left  4315
#   Time to finish   2m 45s,    0.1% completed, time steps left  4314
#   Time to finish   2m 43s,    0.2% completed, time steps left  4313
#   Time to finish   2m 42s,    0.2% completed, time steps left  4312
#   Time to finish   2m 41s,    0.2% completed, time steps left  4311
#   Time to finish   2m 39s,    0.2% completed, time steps left  4310
#   Time to finish   2m 38s,    0.3% completed, time steps left  4309
#   Time to finish   2m 38s,    0.3% completed, time steps left  4308
#   Time to finish   2m 36s,    0.3% completed, time steps left  4307
#   Time to finish   2m 36s,    0.3% completed, time steps left  4306
#   Time to finish   2m 37s,    0.3% completed, time steps left  4305
#   Time to finish   2m 36s,    0.4% completed, time steps left  4304
#   Time to finish   2m 35s,    0.4% completed, time steps left  4303
#   Time to finish   2m 35s,    0.4% completed, time steps left  4302
#   Time to finish   2m 35s,    0.4% completed, time steps left  4301
#   Time to finish   2m 35s,    0.5% completed, time steps left  4300
#   Time to finish   2m 34s,    0.5% completed, time steps left  4299
#   Time to finish   2m 34s,    0.5% completed, time steps left  4298
#   Time to finish   2m 34s,    0.5% completed, time steps left  4297
#   Time to finish   2m 34s,    0.6% completed, time steps left  4296
#   Time to finish   2m 34s,    0.6% completed, time steps left  4295
#   Time to finish   2m 34s,    0.6% completed, time steps left  4294
#   Time to finish   2m 33s,    0.6% completed, time steps left  4293
#   Time to finish   2m 33s,    0.6% completed, time steps left  4292
#   Time to finish   2m 33s,    0.7% completed, time steps left  4291
#   Time to finish   2m 33s,    0.7% completed, time steps left  4290
#   Time to finish   2m 33s,    0.7% completed, time steps left  4289
#   Time to finish   2m 33s,    0.7% completed, time steps left  4288
#   Time to finish   2m 33s,    0.8% completed, time steps left  4287
#   Time to finish   2m 32s,    0.8% completed, time steps left  4286
#   Time to finish   2m 32s,    0.8% completed, time steps left  4285
#   Time to finish   2m 32s,    0.8% completed, time steps left  4284
#   Time to finish   2m 32s,    0.9% completed, time steps left  4283
#   Time to finish   2m 31s,    0.9% completed, time steps left  4282
#   Time to finish   2m 31s,    0.9% completed, time steps left  4281
#   Time to finish   2m 31s,    0.9% completed, time steps left  4280
#   Time to finish   2m 30s,    0.9% completed, time steps left  4279
#   Time to finish   2m 30s,    1.0% completed, time steps left  4278
#   Time to finish   2m 30s,    1.0% completed, time steps left  4277
#   Time to finish   2m 30s,    1.0% completed, time steps left  4276
#   Time to finish   2m 29s,    1.0% completed, time steps left  4275
#   Time to finish   2m 29s,    1.1% completed, time steps left  4274
#   Time to finish   2m 29s,    1.1% completed, time steps left  4273
#   Time to finish   2m 29s,    1.1% completed, time steps left  4272
#   Time to finish   2m 29s,    1.1% completed, time steps left  4271
#   Time to finish   2m 28s,    1.2% completed, time steps left  4270
#   Time to finish   2m 28s,    1.2% completed, time steps left  4269
#   Time to finish   2m 28s,    1.2% completed, time steps left  4268
#   Time to finish   2m 28s,    1.2% completed, time steps left  4267
#   Time to finish   2m 28s,    1.2% completed, time steps left  4266
#   Time to finish   2m 28s,    1.3% completed, time steps left  4265
#   Time to finish   2m 28s,    1.3% completed, time steps left  4264
#   Time to finish   2m 28s,    1.3% completed, time steps left  4263
#   Time to finish   2m 28s,    1.3% completed, time steps left  4262
#   Time to finish   2m 27s,    1.4% completed, time steps left  4261
#   Time to finish   2m 27s,    1.4% completed, time steps left  4260
#   Time to finish   2m 28s,    1.4% completed, time steps left  4259
#   Time to finish   2m 28s,    1.4% completed, time steps left  4258
#   Time to finish   2m 28s,    1.5% completed, time steps left  4257
#   Time to finish   2m 28s,    1.5% completed, time steps left  4256
#   Time to finish   2m 28s,    1.5% completed, time steps left  4255
#   Time to finish   2m 27s,    1.5% completed, time steps left  4254
#   Time to finish   2m 27s,    1.6% completed, time steps left  4253
#   Time to finish   2m 27s,    1.6% completed, time steps left  4252
#   Time to finish   2m 27s,    1.6% completed, time steps left  4251
#   Time to finish   2m 27s,    1.6% completed, time steps left  4250
#   Time to finish   2m 27s,    1.6% completed, time steps left  4249
#   Time to finish   2m 27s,    1.7% completed, time steps left  4248
#   Time to finish   2m 27s,    1.7% completed, time steps left  4247
#   Time to finish   2m 27s,    1.7% completed, time steps left  4246
#   Time to finish   2m 26s,    1.7% completed, time steps left  4245
#   Time to finish   2m 26s,    1.8% completed, time steps left  4244
#   Time to finish   2m 26s,    1.8% completed, time steps left  4243
#   Time to finish   2m 26s,    1.8% completed, time steps left  4242
#   Time to finish   2m 26s,    1.8% completed, time steps left  4241
#   Time to finish   2m 26s,    1.9% completed, time steps left  4240
#   Time to finish   2m 26s,    1.9% completed, time steps left  4239
#   Time to finish   2m 26s,    1.9% completed, time steps left  4238
#   Time to finish   2m 26s,    1.9% completed, time steps left  4237
#   Time to finish   2m 26s,    1.9% completed, time steps left  4236
#   Time to finish   2m 26s,    2.0% completed, time steps left  4235
#   Time to finish   2m 26s,    2.0% completed, time steps left  4234
#   Time to finish   2m 26s,    2.0% completed, time steps left  4233
#   Time to finish   2m 26s,    2.0% completed, time steps left  4232
#   Time to finish   2m 26s,    2.1% completed, time steps left  4231
#   Time to finish   2m 25s,    2.1% completed, time steps left  4230
#   Time to finish   2m 25s,    2.1% completed, time steps left  4229
#   Time to finish   2m 25s,    2.1% completed, time steps left  4228
#   Time to finish   2m 25s,    2.2% completed, time steps left  4227
#   Time to finish   2m 25s,    2.2% completed, time steps left  4226
#   Time to finish   2m 25s,    2.2% completed, time steps left  4225
#   Time to finish   2m 25s,    2.2% completed, time steps left  4224
#   Time to finish   2m 25s,    2.2% completed, time steps left  4223
#   Time to finish   2m 25s,    2.3% completed, time steps left  4222
#   Time to finish   2m 25s,    2.3% completed, time steps left  4221
#   Time to finish   2m 25s,    2.3% completed, time steps left  4220
#   Time to finish   2m 25s,    2.3% completed, time steps left  4219
#   Time to finish   2m 25s,    2.4% completed, time steps left  4218
#   Time to finish   2m 25s,    2.4% completed, time steps left  4217
#   Time to finish   2m 25s,    2.4% completed, time steps left  4216
#   Time to finish   2m 25s,    2.4% completed, time steps left  4215
#   Time to finish   2m 24s,    2.5% completed, time steps left  4214
#   Time to finish   2m 24s,    2.5% completed, time steps left  4213
#   Time to finish   2m 24s,    2.5% completed, time steps left  4212
#   Time to finish   2m 24s,    2.5% completed, time steps left  4211
#   Time to finish   2m 24s,    2.5% completed, time steps left  4210
#   Time to finish   2m 24s,    2.6% completed, time steps left  4209
#   Time to finish   2m 24s,    2.6% completed, time steps left  4208
#   Time to finish   2m 24s,    2.6% completed, time steps left  4207
#   Time to finish   2m 24s,    2.6% completed, time steps left  4206
#   Time to finish   2m 24s,    2.7% completed, time steps left  4205
#   Time to finish   2m 24s,    2.7% completed, time steps left  4204
#   Time to finish   2m 24s,    2.7% completed, time steps left  4203
#   Time to finish   2m 24s,    2.7% completed, time steps left  4202
#   Time to finish   2m 24s,    2.8% completed, time steps left  4201
#   Time to finish   2m 24s,    2.8% completed, time steps left  4200
#   Time to finish   2m 24s,    2.8% completed, time steps left  4199
#   Time to finish   2m 24s,    2.8% completed, time steps left  4198
#   Time to finish   2m 24s,    2.8% completed, time steps left  4197
#   Time to finish   2m 24s,    2.9% completed, time steps left  4196
#   Time to finish   2m 24s,    2.9% completed, time steps left  4195
#   Time to finish   2m 24s,    2.9% completed, time steps left  4194
#   Time to finish   2m 24s,    2.9% completed, time steps left  4193
#   Time to finish   2m 24s,    3.0% completed, time steps left  4192
#   Time to finish   2m 24s,    3.0% completed, time steps left  4191
#   Time to finish   2m 24s,    3.0% completed, time steps left  4190
#   Time to finish   2m 24s,    3.0% completed, time steps left  4189
#   Time to finish   2m 24s,    3.1% completed, time steps left  4188
#   Time to finish   2m 24s,    3.1% completed, time steps left  4187
#   Time to finish   2m 23s,    3.1% completed, time steps left  4186
#   Time to finish   2m 23s,    3.1% completed, time steps left  4185
#   Time to finish   2m 23s,    3.1% completed, time steps left  4184
#   Time to finish   2m 23s,    3.2% completed, time steps left  4183
#   Time to finish   2m 23s,    3.2% completed, time steps left  4182
#   Time to finish   2m 23s,    3.2% completed, time steps left  4181
#   Time to finish   2m 23s,    3.2% completed, time steps left  4180
#   Time to finish   2m 23s,    3.3% completed, time steps left  4179
#   Time to finish   2m 24s,    3.3% completed, time steps left  4178
#   Time to finish   2m 24s,    3.3% completed, time steps left  4177
#   Time to finish   2m 24s,    3.3% completed, time steps left  4176
#   Time to finish   2m 24s,    3.4% completed, time steps left  4175
#   Time to finish   2m 24s,    3.4% completed, time steps left  4174
#   Time to finish   2m 24s,    3.4% completed, time steps left  4173
#   Time to finish   2m 24s,    3.4% completed, time steps left  4172
#   Time to finish   2m 24s,    3.4% completed, time steps left  4171
#   Time to finish   2m 24s,    3.5% completed, time steps left  4170
#   Time to finish   2m 24s,    3.5% completed, time steps left  4169
#   Time to finish   2m 23s,    3.5% completed, time steps left  4168
#   Time to finish   2m 23s,    3.5% completed, time steps left  4167
#   Time to finish   2m 23s,    3.6% completed, time steps left  4166
#   Time to finish   2m 23s,    3.6% completed, time steps left  4165
#   Time to finish   2m 23s,    3.6% completed, time steps left  4164
#   Time to finish   2m 23s,    3.6% completed, time steps left  4163
#   Time to finish   2m 23s,    3.7% completed, time steps left  4162
#   Time to finish   2m 23s,    3.7% completed, time steps left  4161
#   Time to finish   2m 23s,    3.7% completed, time steps left  4160
#   Time to finish   2m 23s,    3.7% completed, time steps left  4159
#   Time to finish   2m 23s,    3.8% completed, time steps left  4158
#   Time to finish   2m 24s,    3.8% completed, time steps left  4157
#   Time to finish   2m 24s,    3.8% completed, time steps left  4156
#   Time to finish   2m 24s,    3.8% completed, time steps left  4155
#   Time to finish   2m 24s,    3.8% completed, time steps left  4154
#   Time to finish   2m 24s,    3.9% completed, time steps left  4153
#   Time to finish   2m 24s,    3.9% completed, time steps left  4152
#   Time to finish   2m 24s,    3.9% completed, time steps left  4151
#   Time to finish   2m 24s,    3.9% completed, time steps left  4150
#   Time to finish   2m 24s,    4.0% completed, time steps left  4149
#   Time to finish   2m 24s,    4.0% completed, time steps left  4148
#   Time to finish   2m 24s,    4.0% completed, time steps left  4147
#   Time to finish   2m 24s,    4.0% completed, time steps left  4146
#   Time to finish   2m 24s,    4.1% completed, time steps left  4145
#   Time to finish   2m 24s,    4.1% completed, time steps left  4144
#   Time to finish   2m 24s,    4.1% completed, time steps left  4143
#   Time to finish   2m 24s,    4.1% completed, time steps left  4142
#   Time to finish   2m 24s,    4.1% completed, time steps left  4141
#   Time to finish   2m 24s,    4.2% completed, time steps left  4140
#   Time to finish   2m 29s,    4.2% completed, time steps left  4139
#   Time to finish   2m 29s,    4.2% completed, time steps left  4138
#   Time to finish   2m 29s,    4.2% completed, time steps left  4137
#   Time to finish   2m 29s,    4.3% completed, time steps left  4136
#   Time to finish   2m 29s,    4.3% completed, time steps left  4135
#   Time to finish   2m 29s,    4.3% completed, time steps left  4134
#   Time to finish   2m 29s,    4.3% completed, time steps left  4133
#   Time to finish   2m 29s,    4.4% completed, time steps left  4132
#   Time to finish   2m 29s,    4.4% completed, time steps left  4131
#   Time to finish   2m 30s,    4.4% completed, time steps left  4130
#   Time to finish   2m 30s,    4.4% completed, time steps left  4129
#   Time to finish   2m 30s,    4.4% completed, time steps left  4128
#   Time to finish   2m 30s,    4.5% completed, time steps left  4127
#   Time to finish   2m 30s,    4.5% completed, time steps left  4126
#   Time to finish   2m 30s,    4.5% completed, time steps left  4125
#   Time to finish   2m 30s,    4.5% completed, time steps left  4124
#   Time to finish   2m 30s,    4.6% completed, time steps left  4123
#   Time to finish   2m 30s,    4.6% completed, time steps left  4122
#   Time to finish   2m 30s,    4.6% completed, time steps left  4121
#   Time to finish   2m 30s,    4.6% completed, time steps left  4120
#   Time to finish   2m 30s,    4.7% completed, time steps left  4119
#   Time to finish   2m 30s,    4.7% completed, time steps left  4118
#   Time to finish   2m 30s,    4.7% completed, time steps left  4117
#   Time to finish   2m 30s,    4.7% completed, time steps left  4116
#   Time to finish   2m 30s,    4.7% completed, time steps left  4115
#   Time to finish   2m 30s,    4.8% completed, time steps left  4114
#   Time to finish   2m 30s,    4.8% completed, time steps left  4113
#   Time to finish   2m 30s,    4.8% completed, time steps left  4112
#   Time to finish   2m 30s,    4.8% completed, time steps left  4111
#   Time to finish   2m 30s,    4.9% completed, time steps left  4110
#   Time to finish   2m 30s,    4.9% completed, time steps left  4109
#   Time to finish   2m 30s,    4.9% completed, time steps left  4108
#   Time to finish   2m 30s,    4.9% completed, time steps left  4107
#   Time to finish   2m 30s,    5.0% completed, time steps left  4106
#   Time to finish   2m 30s,    5.0% completed, time steps left  4105
#   Time to finish   2m 30s,    5.0% completed, time steps left  4104
#   Time to finish   2m 30s,    5.0% completed, time steps left  4103
#   Time to finish   2m 30s,    5.0% completed, time steps left  4102
#   Time to finish   2m 30s,    5.1% completed, time steps left  4101
#   Time to finish   2m 30s,    5.1% completed, time steps left  4100
#   Time to finish   2m 29s,    5.1% completed, time steps left  4099
#   Time to finish   2m 29s,    5.1% completed, time steps left  4098
#   Time to finish   2m 29s,    5.2% completed, time steps left  4097
#   Time to finish   2m 29s,    5.2% completed, time steps left  4096
#   Time to finish   2m 29s,    5.2% completed, time steps left  4095
#   Time to finish   2m 29s,    5.2% completed, time steps left  4094
#   Time to finish   2m 29s,    5.3% completed, time steps left  4093
#   Time to finish   2m 29s,    5.3% completed, time steps left  4092
#   Time to finish   2m 29s,    5.3% completed, time steps left  4091
#   Time to finish   2m 29s,    5.3% completed, time steps left  4090
#   Time to finish   2m 29s,    5.3% completed, time steps left  4089
#   Time to finish   2m 29s,    5.4% completed, time steps left  4088
#   Time to finish   2m 28s,    5.4% completed, time steps left  4087
#   Time to finish   2m 28s,    5.4% completed, time steps left  4086
#   Time to finish   2m 28s,    5.4% completed, time steps left  4085
#   Time to finish   2m 28s,    5.5% completed, time steps left  4084
#   Time to finish   2m 28s,    5.5% completed, time steps left  4083
#   Time to finish   2m 28s,    5.5% completed, time steps left  4082
#   Time to finish   2m 28s,    5.5% completed, time steps left  4081
#   Time to finish   2m 28s,    5.6% completed, time steps left  4080
#   Time to finish   2m 28s,    5.6% completed, time steps left  4079
#   Time to finish   2m 28s,    5.6% completed, time steps left  4078
#   Time to finish   2m 28s,    5.6% completed, time steps left  4077
#   Time to finish   2m 28s,    5.6% completed, time steps left  4076
#   Time to finish   2m 28s,    5.7% completed, time steps left  4075
#   Time to finish   2m 28s,    5.7% completed, time steps left  4074
#   Time to finish   2m 28s,    5.7% completed, time steps left  4073
#   Time to finish   2m 28s,    5.7% completed, time steps left  4072
#   Time to finish   2m 28s,    5.8% completed, time steps left  4071
#   Time to finish   2m 28s,    5.8% completed, time steps left  4070
#   Time to finish   2m 28s,    5.8% completed, time steps left  4069
#   Time to finish   2m 28s,    5.8% completed, time steps left  4068
#   Time to finish   2m 28s,    5.9% completed, time steps left  4067
#   Time to finish   2m 27s,    5.9% completed, time steps left  4066
#   Time to finish   2m 27s,    5.9% completed, time steps left  4065
#   Time to finish   2m 27s,    5.9% completed, time steps left  4064
#   Time to finish   2m 27s,    5.9% completed, time steps left  4063
#   Time to finish   2m 27s,    6.0% completed, time steps left  4062
#   Time to finish   2m 28s,    6.0% completed, time steps left  4061
#   Time to finish   2m 28s,    6.0% completed, time steps left  4060
#   Time to finish   2m 29s,    6.0% completed, time steps left  4059
#   Time to finish   2m 29s,    6.1% completed, time steps left  4058
#   Time to finish   2m 29s,    6.1% completed, time steps left  4057
#   Time to finish   2m 29s,    6.1% completed, time steps left  4056
#   Time to finish   2m 29s,    6.1% completed, time steps left  4055
#   Time to finish   2m 29s,    6.2% completed, time steps left  4054
#   Time to finish   2m 29s,    6.2% completed, time steps left  4053
#   Time to finish   2m 29s,    6.2% completed, time steps left  4052
#   Time to finish   2m 29s,    6.2% completed, time steps left  4051
#   Time to finish   2m 29s,    6.2% completed, time steps left  4050
#   Time to finish   2m 29s,    6.3% completed, time steps left  4049
#   Time to finish   2m 29s,    6.3% completed, time steps left  4048
#   Time to finish   2m 29s,    6.3% completed, time steps left  4047
#   Time to finish   2m 29s,    6.3% completed, time steps left  4046
#   Time to finish   2m 29s,    6.4% completed, time steps left  4045
#   Time to finish   2m 29s,    6.4% completed, time steps left  4044
#   Time to finish   2m 29s,    6.4% completed, time steps left  4043
#   Time to finish   2m 29s,    6.4% completed, time steps left  4042
#   Time to finish   2m 29s,    6.5% completed, time steps left  4041
#   Time to finish   2m 29s,    6.5% completed, time steps left  4040
#   Time to finish   2m 29s,    6.5% completed, time steps left  4039
#   Time to finish   2m 29s,    6.5% completed, time steps left  4038
#   Time to finish   2m 29s,    6.6% completed, time steps left  4037
#   Time to finish   2m 29s,    6.6% completed, time steps left  4036
#   Time to finish   2m 29s,    6.6% completed, time steps left  4035
#   Time to finish   2m 29s,    6.6% completed, time steps left  4034
#   Time to finish   2m 28s,    6.6% completed, time steps left  4033
#   Time to finish   2m 28s,    6.7% completed, time steps left  4032
#   Time to finish   2m 28s,    6.7% completed, time steps left  4031
#   Time to finish   2m 28s,    6.7% completed, time steps left  4030
#   Time to finish   2m 28s,    6.7% completed, time steps left  4029
#   Time to finish   2m 28s,    6.8% completed, time steps left  4028
#   Time to finish   2m 28s,    6.8% completed, time steps left  4027
#   Time to finish   2m 28s,    6.8% completed, time steps left  4026
#   Time to finish   2m 28s,    6.8% completed, time steps left  4025
#   Time to finish   2m 28s,    6.9% completed, time steps left  4024
#   Time to finish   2m 28s,    6.9% completed, time steps left  4023
#   Time to finish   2m 28s,    6.9% completed, time steps left  4022
#   Time to finish   2m 28s,    6.9% completed, time steps left  4021
#   Time to finish   2m 28s,    6.9% completed, time steps left  4020
#   Time to finish   2m 28s,    7.0% completed, time steps left  4019
#   Time to finish   2m 28s,    7.0% completed, time steps left  4018
#   Time to finish   2m 28s,    7.0% completed, time steps left  4017
#   Time to finish   2m 28s,    7.0% completed, time steps left  4016
#   Time to finish   2m 27s,    7.1% completed, time steps left  4015
#   Time to finish   2m 27s,    7.1% completed, time steps left  4014
#   Time to finish   2m 27s,    7.1% completed, time steps left  4013
#   Time to finish   2m 27s,    7.1% completed, time steps left  4012
#   Time to finish   2m 27s,    7.2% completed, time steps left  4011
#   Time to finish   2m 27s,    7.2% completed, time steps left  4010
#   Time to finish   2m 27s,    7.2% completed, time steps left  4009
#   Time to finish   2m 27s,    7.2% completed, time steps left  4008
#   Time to finish   2m 27s,    7.2% completed, time steps left  4007
#   Time to finish   2m 28s,    7.3% completed, time steps left  4006
#   Time to finish   2m 28s,    7.3% completed, time steps left  4005
#   Time to finish   2m 28s,    7.3% completed, time steps left  4004
#   Time to finish   2m 28s,    7.3% completed, time steps left  4003
#   Time to finish   2m 28s,    7.4% completed, time steps left  4002
#   Time to finish   2m 28s,    7.4% completed, time steps left  4001
#   Time to finish   2m 28s,    7.4% completed, time steps left  4000
#   Time to finish   2m 28s,    7.4% completed, time steps left  3999
#   Time to finish   2m 28s,    7.5% completed, time steps left  3998
#   Time to finish   2m 28s,    7.5% completed, time steps left  3997
#   Time to finish   2m 28s,    7.5% completed, time steps left  3996
#   Time to finish   2m 28s,    7.5% completed, time steps left  3995
#   Time to finish   2m 28s,    7.5% completed, time steps left  3994
#   Time to finish   2m 28s,    7.6% completed, time steps left  3993
#   Time to finish   2m 28s,    7.6% completed, time steps left  3992
#   Time to finish   2m 28s,    7.6% completed, time steps left  3991
#   Time to finish   2m 28s,    7.6% completed, time steps left  3990
#   Time to finish   2m 28s,    7.7% completed, time steps left  3989
#   Time to finish   2m 28s,    7.7% completed, time steps left  3988
#   Time to finish   2m 28s,    7.7% completed, time steps left  3987
#   Time to finish   2m 28s,    7.7% completed, time steps left  3986
#   Time to finish   2m 28s,    7.8% completed, time steps left  3985
#   Time to finish   2m 28s,    7.8% completed, time steps left  3984
#   Time to finish   2m 29s,    7.8% completed, time steps left  3983
#   Time to finish   2m 29s,    7.8% completed, time steps left  3982
#   Time to finish   2m 29s,    7.8% completed, time steps left  3981
#   Time to finish   2m 29s,    7.9% completed, time steps left  3980
#   Time to finish   2m 29s,    7.9% completed, time steps left  3979
#   Time to finish   2m 29s,    7.9% completed, time steps left  3978
#   Time to finish   2m 29s,    7.9% completed, time steps left  3977
#   Time to finish   2m 29s,    8.0% completed, time steps left  3976
#   Time to finish   2m 29s,    8.0% completed, time steps left  3975
#   Time to finish   2m 29s,    8.0% completed, time steps left  3974
#   Time to finish   2m 29s,    8.0% completed, time steps left  3973
#   Time to finish   2m 29s,    8.1% completed, time steps left  3972
#   Time to finish   2m 29s,    8.1% completed, time steps left  3971
#   Time to finish   2m 29s,    8.1% completed, time steps left  3970
#   Time to finish   2m 29s,    8.1% completed, time steps left  3969
#   Time to finish   2m 29s,    8.1% completed, time steps left  3968
#   Time to finish   2m 29s,    8.2% completed, time steps left  3967
#   Time to finish   2m 29s,    8.2% completed, time steps left  3966
#   Time to finish   2m 29s,    8.2% completed, time steps left  3965
#   Time to finish   2m 29s,    8.2% completed, time steps left  3964
#   Time to finish   2m 29s,    8.3% completed, time steps left  3963
#   Time to finish   2m 29s,    8.3% completed, time steps left  3962
#   Time to finish   2m 29s,    8.3% completed, time steps left  3961
#   Time to finish   2m 29s,    8.3% completed, time steps left  3960
#   Time to finish   2m 32s,    8.4% completed, time steps left  3959
#   Time to finish   2m 32s,    8.4% completed, time steps left  3958
#   Time to finish   2m 32s,    8.4% completed, time steps left  3957
#   Time to finish   2m 32s,    8.4% completed, time steps left  3956
#   Time to finish   2m 32s,    8.4% completed, time steps left  3955
#   Time to finish   2m 32s,    8.5% completed, time steps left  3954
#   Time to finish   2m 32s,    8.5% completed, time steps left  3953
#   Time to finish   2m 32s,    8.5% completed, time steps left  3952
#   Time to finish   2m 32s,    8.5% completed, time steps left  3951
#   Time to finish   2m 32s,    8.6% completed, time steps left  3950
#   Time to finish   2m 32s,    8.6% completed, time steps left  3949
#   Time to finish   2m 32s,    8.6% completed, time steps left  3948
#   Time to finish   2m 32s,    8.6% completed, time steps left  3947
#   Time to finish   2m 32s,    8.7% completed, time steps left  3946
#   Time to finish   2m 32s,    8.7% completed, time steps left  3945
#   Time to finish   2m 32s,    8.7% completed, time steps left  3944
#   Time to finish   2m 32s,    8.7% completed, time steps left  3943
#   Time to finish   2m 32s,    8.8% completed, time steps left  3942
#   Time to finish   2m 32s,    8.8% completed, time steps left  3941
#   Time to finish   2m 32s,    8.8% completed, time steps left  3940
#   Time to finish   2m 32s,    8.8% completed, time steps left  3939
#   Time to finish   2m 32s,    8.8% completed, time steps left  3938
#   Time to finish   2m 32s,    8.9% completed, time steps left  3937
#   Time to finish   2m 32s,    8.9% completed, time steps left  3936
#   Time to finish   2m 32s,    8.9% completed, time steps left  3935
#   Time to finish   2m 32s,    8.9% completed, time steps left  3934
#   Time to finish   2m 32s,    9.0% completed, time steps left  3933
#   Time to finish   2m 32s,    9.0% completed, time steps left  3932
#   Time to finish   2m 32s,    9.0% completed, time steps left  3931
#   Time to finish   2m 32s,    9.0% completed, time steps left  3930
#   Time to finish   2m 32s,    9.1% completed, time steps left  3929
#   Time to finish   2m 32s,    9.1% completed, time steps left  3928
#   Time to finish   2m 32s,    9.1% completed, time steps left  3927
#   Time to finish   2m 32s,    9.1% completed, time steps left  3926
#   Time to finish   2m 32s,    9.1% completed, time steps left  3925
#   Time to finish   2m 32s,    9.2% completed, time steps left  3924
#   Time to finish   2m 32s,    9.2% completed, time steps left  3923
#   Time to finish   2m 32s,    9.2% completed, time steps left  3922
#   Time to finish   2m 33s,    9.2% completed, time steps left  3921
#   Time to finish   2m 33s,    9.3% completed, time steps left  3920
#   Time to finish   2m 33s,    9.3% completed, time steps left  3919
#   Time to finish   2m 33s,    9.3% completed, time steps left  3918
#   Time to finish   2m 33s,    9.3% completed, time steps left  3917
#   Time to finish   2m 33s,    9.4% completed, time steps left  3916
#   Time to finish   2m 33s,    9.4% completed, time steps left  3915
#   Time to finish   2m 33s,    9.4% completed, time steps left  3914
#   Time to finish   2m 33s,    9.4% completed, time steps left  3913
#   Time to finish   2m 33s,    9.4% completed, time steps left  3912
#   Time to finish   2m 33s,    9.5% completed, time steps left  3911
#   Time to finish   2m 33s,    9.5% completed, time steps left  3910
#   Time to finish   2m 33s,    9.5% completed, time steps left  3909
#   Time to finish   2m 33s,    9.5% completed, time steps left  3908
#   Time to finish   2m 33s,    9.6% completed, time steps left  3907
#   Time to finish   2m 33s,    9.6% completed, time steps left  3906
#   Time to finish   2m 33s,    9.6% completed, time steps left  3905
#   Time to finish   2m 33s,    9.6% completed, time steps left  3904
#   Time to finish   2m 33s,    9.7% completed, time steps left  3903
#   Time to finish   2m 33s,    9.7% completed, time steps left  3902
#   Time to finish   2m 33s,    9.7% completed, time steps left  3901
#   Time to finish   2m 33s,    9.7% completed, time steps left  3900
#   Time to finish   2m 33s,    9.7% completed, time steps left  3899
#   Time to finish   2m 33s,    9.8% completed, time steps left  3898
#   Time to finish   2m 33s,    9.8% completed, time steps left  3897
#   Time to finish   2m 33s,    9.8% completed, time steps left  3896
#   Time to finish   2m 33s,    9.8% completed, time steps left  3895
#   Time to finish   2m 33s,    9.9% completed, time steps left  3894
#   Time to finish   2m 33s,    9.9% completed, time steps left  3893
#   Time to finish   2m 33s,    9.9% completed, time steps left  3892
#   Time to finish   2m 33s,    9.9% completed, time steps left  3891
#   Time to finish   2m 33s,   10.0% completed, time steps left  3890
#   Time to finish   2m 33s,   10.0% completed, time steps left  3889
#   Time to finish   2m 33s,   10.0% completed, time steps left  3888
#   Time to finish   2m 33s,   10.0% completed, time steps left  3887
#   Time to finish   2m 33s,   10.0% completed, time steps left  3886
#   Time to finish   2m 33s,   10.1% completed, time steps left  3885
#   Time to finish   2m 33s,   10.1% completed, time steps left  3884
#   Time to finish   2m 33s,   10.1% completed, time steps left  3883
#   Time to finish   2m 33s,   10.1% completed, time steps left  3882
#   Time to finish   2m 33s,   10.2% completed, time steps left  3881
#   Time to finish   2m 33s,   10.2% completed, time steps left  3880
#   Time to finish   2m 33s,   10.2% completed, time steps left  3879
#   Time to finish   2m 34s,   10.2% completed, time steps left  3878
#   Time to finish   2m 34s,   10.3% completed, time steps left  3877
#   Time to finish   2m 34s,   10.3% completed, time steps left  3876
#   Time to finish   2m 34s,   10.3% completed, time steps left  3875
#   Time to finish   2m 34s,   10.3% completed, time steps left  3874
#   Time to finish   2m 34s,   10.3% completed, time steps left  3873
#   Time to finish   2m 34s,   10.4% completed, time steps left  3872
#   Time to finish   2m 34s,   10.4% completed, time steps left  3871
#   Time to finish   2m 34s,   10.4% completed, time steps left  3870
#   Time to finish   2m 34s,   10.4% completed, time steps left  3869
#   Time to finish   2m 34s,   10.5% completed, time steps left  3868
#   Time to finish   2m 34s,   10.5% completed, time steps left  3867
#   Time to finish   2m 34s,   10.5% completed, time steps left  3866
#   Time to finish   2m 34s,   10.5% completed, time steps left  3865
#   Time to finish   2m 34s,   10.6% completed, time steps left  3864
#   Time to finish   2m 34s,   10.6% completed, time steps left  3863
#   Time to finish   2m 34s,   10.6% completed, time steps left  3862
#   Time to finish   2m 34s,   10.6% completed, time steps left  3861
#   Time to finish   2m 34s,   10.6% completed, time steps left  3860
#   Time to finish   2m 34s,   10.7% completed, time steps left  3859
#   Time to finish   2m 34s,   10.7% completed, time steps left  3858
#   Time to finish   2m 34s,   10.7% completed, time steps left  3857
#   Time to finish   2m 34s,   10.7% completed, time steps left  3856
#   Time to finish   2m 34s,   10.8% completed, time steps left  3855
#   Time to finish   2m 34s,   10.8% completed, time steps left  3854
#   Time to finish   2m 34s,   10.8% completed, time steps left  3853
#   Time to finish   2m 34s,   10.8% completed, time steps left  3852
#   Time to finish   2m 34s,   10.9% completed, time steps left  3851
#   Time to finish   2m 34s,   10.9% completed, time steps left  3850
#   Time to finish   2m 34s,   10.9% completed, time steps left  3849
#   Time to finish   2m 34s,   10.9% completed, time steps left  3848
#   Time to finish   2m 34s,   10.9% completed, time steps left  3847
#   Time to finish   2m 34s,   11.0% completed, time steps left  3846
#   Time to finish   2m 34s,   11.0% completed, time steps left  3845
#   Time to finish   2m 34s,   11.0% completed, time steps left  3844
#   Time to finish   2m 34s,   11.0% completed, time steps left  3843
#   Time to finish   2m 34s,   11.1% completed, time steps left  3842
#   Time to finish   2m 34s,   11.1% completed, time steps left  3841
#   Time to finish   2m 34s,   11.1% completed, time steps left  3840
#   Time to finish   2m 34s,   11.1% completed, time steps left  3839
#   Time to finish   2m 34s,   11.2% completed, time steps left  3838
#   Time to finish   2m 34s,   11.2% completed, time steps left  3837
#   Time to finish   2m 34s,   11.2% completed, time steps left  3836
#   Time to finish   2m 34s,   11.2% completed, time steps left  3835
#   Time to finish   2m 34s,   11.2% completed, time steps left  3834
#   Time to finish   2m 34s,   11.3% completed, time steps left  3833
#   Time to finish   2m 34s,   11.3% completed, time steps left  3832
#   Time to finish   2m 34s,   11.3% completed, time steps left  3831
#   Time to finish   2m 34s,   11.3% completed, time steps left  3830
#   Time to finish   2m 34s,   11.4% completed, time steps left  3829
#   Time to finish   2m 34s,   11.4% completed, time steps left  3828
#   Time to finish   2m 34s,   11.4% completed, time steps left  3827
#   Time to finish   2m 34s,   11.4% completed, time steps left  3826
#   Time to finish   2m 34s,   11.5% completed, time steps left  3825
#   Time to finish   2m 34s,   11.5% completed, time steps left  3824
#   Time to finish   2m 34s,   11.5% completed, time steps left  3823
#   Time to finish   2m 34s,   11.5% completed, time steps left  3822
#   Time to finish   2m 34s,   11.6% completed, time steps left  3821
#   Time to finish   2m 34s,   11.6% completed, time steps left  3820
#   Time to finish   2m 34s,   11.6% completed, time steps left  3819
#   Time to finish   2m 34s,   11.6% completed, time steps left  3818
#   Time to finish   2m 34s,   11.6% completed, time steps left  3817
#   Time to finish   2m 35s,   11.7% completed, time steps left  3816
#   Time to finish   2m 35s,   11.7% completed, time steps left  3815
#   Time to finish   2m 35s,   11.7% completed, time steps left  3814
#   Time to finish   2m 35s,   11.7% completed, time steps left  3813
#   Time to finish   2m 35s,   11.8% completed, time steps left  3812
#   Time to finish   2m 35s,   11.8% completed, time steps left  3811
#   Time to finish   2m 35s,   11.8% completed, time steps left  3810
#   Time to finish   2m 35s,   11.8% completed, time steps left  3809
#   Time to finish   2m 35s,   11.9% completed, time steps left  3808
#   Time to finish   2m 35s,   11.9% completed, time steps left  3807
#   Time to finish   2m 35s,   11.9% completed, time steps left  3806
#   Time to finish   2m 35s,   11.9% completed, time steps left  3805
#   Time to finish   2m 35s,   11.9% completed, time steps left  3804
#   Time to finish   2m 35s,   12.0% completed, time steps left  3803
#   Time to finish   2m 35s,   12.0% completed, time steps left  3802
#   Time to finish   2m 35s,   12.0% completed, time steps left  3801
#   Time to finish   2m 35s,   12.0% completed, time steps left  3800
#   Time to finish   2m 35s,   12.1% completed, time steps left  3799
#   Time to finish   2m 35s,   12.1% completed, time steps left  3798
#   Time to finish   2m 35s,   12.1% completed, time steps left  3797
#   Time to finish   2m 35s,   12.1% completed, time steps left  3796
#   Time to finish   2m 35s,   12.2% completed, time steps left  3795
#   Time to finish   2m 35s,   12.2% completed, time steps left  3794
#   Time to finish   2m 35s,   12.2% completed, time steps left  3793
#   Time to finish   2m 35s,   12.2% completed, time steps left  3792
#   Time to finish   2m 35s,   12.2% completed, time steps left  3791
#   Time to finish   2m 35s,   12.3% completed, time steps left  3790
#   Time to finish   2m 35s,   12.3% completed, time steps left  3789
#   Time to finish   2m 35s,   12.3% completed, time steps left  3788
#   Time to finish   2m 35s,   12.3% completed, time steps left  3787
#   Time to finish   2m 35s,   12.4% completed, time steps left  3786
#   Time to finish   2m 35s,   12.4% completed, time steps left  3785
#   Time to finish   2m 35s,   12.4% completed, time steps left  3784
#   Time to finish   2m 35s,   12.4% completed, time steps left  3783
#   Time to finish   2m 35s,   12.5% completed, time steps left  3782
#   Time to finish   2m 35s,   12.5% completed, time steps left  3781
#   Time to finish   2m 35s,   12.5% completed, time steps left  3780
#   Time to finish   2m 37s,   12.5% completed, time steps left  3779
#   Time to finish   2m 37s,   12.5% completed, time steps left  3778
#   Time to finish   2m 37s,   12.6% completed, time steps left  3777
#   Time to finish   2m 37s,   12.6% completed, time steps left  3776
#   Time to finish   2m 37s,   12.6% completed, time steps left  3775
#   Time to finish   2m 37s,   12.6% completed, time steps left  3774
#   Time to finish   2m 37s,   12.7% completed, time steps left  3773
#   Time to finish   2m 37s,   12.7% completed, time steps left  3772
#   Time to finish   2m 37s,   12.7% completed, time steps left  3771
#   Time to finish   2m 37s,   12.7% completed, time steps left  3770
#   Time to finish   2m 37s,   12.8% completed, time steps left  3769
#   Time to finish   2m 37s,   12.8% completed, time steps left  3768
#   Time to finish   2m 36s,   12.8% completed, time steps left  3767
#   Time to finish   2m 36s,   12.8% completed, time steps left  3766
#   Time to finish   2m 36s,   12.8% completed, time steps left  3765
#   Time to finish   2m 36s,   12.9% completed, time steps left  3764
#   Time to finish   2m 36s,   12.9% completed, time steps left  3763
#   Time to finish   2m 36s,   12.9% completed, time steps left  3762
#   Time to finish   2m 36s,   12.9% completed, time steps left  3761
#   Time to finish   2m 36s,   13.0% completed, time steps left  3760
#   Time to finish   2m 36s,   13.0% completed, time steps left  3759
#   Time to finish   2m 36s,   13.0% completed, time steps left  3758
#   Time to finish   2m 36s,   13.0% completed, time steps left  3757
#   Time to finish   2m 36s,   13.1% completed, time steps left  3756
#   Time to finish   2m 36s,   13.1% completed, time steps left  3755
#   Time to finish   2m 36s,   13.1% completed, time steps left  3754
#   Time to finish   2m 36s,   13.1% completed, time steps left  3753
#   Time to finish   2m 36s,   13.1% completed, time steps left  3752
#   Time to finish   2m 36s,   13.2% completed, time steps left  3751
#   Time to finish   2m 36s,   13.2% completed, time steps left  3750
#   Time to finish   2m 36s,   13.2% completed, time steps left  3749
#   Time to finish   2m 36s,   13.2% completed, time steps left  3748
#   Time to finish   2m 35s,   13.3% completed, time steps left  3747
#   Time to finish   2m 35s,   13.3% completed, time steps left  3746
#   Time to finish   2m 35s,   13.3% completed, time steps left  3745
#   Time to finish   2m 35s,   13.3% completed, time steps left  3744
#   Time to finish   2m 35s,   13.4% completed, time steps left  3743
#   Time to finish   2m 35s,   13.4% completed, time steps left  3742
#   Time to finish   2m 35s,   13.4% completed, time steps left  3741
#   Time to finish   2m 35s,   13.4% completed, time steps left  3740
#   Time to finish   2m 35s,   13.4% completed, time steps left  3739
#   Time to finish   2m 35s,   13.5% completed, time steps left  3738
#   Time to finish   2m 35s,   13.5% completed, time steps left  3737
#   Time to finish   2m 35s,   13.5% completed, time steps left  3736
#   Time to finish   2m 35s,   13.5% completed, time steps left  3735
#   Time to finish   2m 35s,   13.6% completed, time steps left  3734
#   Time to finish   2m 35s,   13.6% completed, time steps left  3733
#   Time to finish   2m 35s,   13.6% completed, time steps left  3732
#   Time to finish   2m 35s,   13.6% completed, time steps left  3731
#   Time to finish   2m 35s,   13.7% completed, time steps left  3730
#   Time to finish   2m 35s,   13.7% completed, time steps left  3729
#   Time to finish   2m 35s,   13.7% completed, time steps left  3728
#   Time to finish   2m 35s,   13.7% completed, time steps left  3727
#   Time to finish   2m 35s,   13.8% completed, time steps left  3726
#   Time to finish   2m 34s,   13.8% completed, time steps left  3725
#   Time to finish   2m 34s,   13.8% completed, time steps left  3724
#   Time to finish   2m 34s,   13.8% completed, time steps left  3723
#   Time to finish   2m 34s,   13.8% completed, time steps left  3722
#   Time to finish   2m 34s,   13.9% completed, time steps left  3721
#   Time to finish   2m 34s,   13.9% completed, time steps left  3720
#   Time to finish   2m 34s,   13.9% completed, time steps left  3719
#   Time to finish   2m 34s,   13.9% completed, time steps left  3718
#   Time to finish   2m 34s,   14.0% completed, time steps left  3717
#   Time to finish   2m 34s,   14.0% completed, time steps left  3716
#   Time to finish   2m 34s,   14.0% completed, time steps left  3715
#   Time to finish   2m 34s,   14.0% completed, time steps left  3714
#   Time to finish   2m 34s,   14.1% completed, time steps left  3713
#   Time to finish   2m 34s,   14.1% completed, time steps left  3712
#   Time to finish   2m 34s,   14.1% completed, time steps left  3711
#   Time to finish   2m 34s,   14.1% completed, time steps left  3710
#   Time to finish   2m 34s,   14.1% completed, time steps left  3709
#   Time to finish   2m 34s,   14.2% completed, time steps left  3708
#   Time to finish   2m 34s,   14.2% completed, time steps left  3707
#   Time to finish   2m 34s,   14.2% completed, time steps left  3706
#   Time to finish   2m 33s,   14.2% completed, time steps left  3705
#   Time to finish   2m 33s,   14.3% completed, time steps left  3704
#   Time to finish   2m 33s,   14.3% completed, time steps left  3703
#   Time to finish   2m 33s,   14.3% completed, time steps left  3702
#   Time to finish   2m 33s,   14.3% completed, time steps left  3701
#   Time to finish   2m 33s,   14.4% completed, time steps left  3700
#   Time to finish   2m 33s,   14.4% completed, time steps left  3699
#   Time to finish   2m 33s,   14.4% completed, time steps left  3698
#   Time to finish   2m 33s,   14.4% completed, time steps left  3697
#   Time to finish   2m 33s,   14.4% completed, time steps left  3696
#   Time to finish   2m 33s,   14.5% completed, time steps left  3695
#   Time to finish   2m 33s,   14.5% completed, time steps left  3694
#   Time to finish   2m 33s,   14.5% completed, time steps left  3693
#   Time to finish   2m 33s,   14.5% completed, time steps left  3692
#   Time to finish   2m 33s,   14.6% completed, time steps left  3691
#   Time to finish   2m 32s,   14.6% completed, time steps left  3690
#   Time to finish   2m 32s,   14.6% completed, time steps left  3689
#   Time to finish   2m 32s,   14.6% completed, time steps left  3688
#   Time to finish   2m 32s,   14.7% completed, time steps left  3687
#   Time to finish   2m 32s,   14.7% completed, time steps left  3686
#   Time to finish   2m 32s,   14.7% completed, time steps left  3685
#   Time to finish   2m 32s,   14.7% completed, time steps left  3684
#   Time to finish   2m 32s,   14.7% completed, time steps left  3683
#   Time to finish   2m 32s,   14.8% completed, time steps left  3682
#   Time to finish   2m 32s,   14.8% completed, time steps left  3681
#   Time to finish   2m 32s,   14.8% completed, time steps left  3680
#   Time to finish   2m 32s,   14.8% completed, time steps left  3679
# ...
#   Time to finish  10s,   94.7% completed, time steps left  229
#   Time to finish  10s,   94.7% completed, time steps left  228
#   Time to finish  10s,   94.7% completed, time steps left  227
#   Time to finish  10s,   94.8% completed, time steps left  226
#   Time to finish  10s,   94.8% completed, time steps left  225
#   Time to finish  10s,   94.8% completed, time steps left  224
#   Time to finish  10s,   94.8% completed, time steps left  223
#   Time to finish  10s,   94.9% completed, time steps left  222
#   Time to finish  10s,   94.9% completed, time steps left  221
#   Time to finish  10s,   94.9% completed, time steps left  220
#   Time to finish  10s,   94.9% completed, time steps left  219
#   Time to finish  10s,   95.0% completed, time steps left  218
#   Time to finish  10s,   95.0% completed, time steps left  217
#   Time to finish  10s,   95.0% completed, time steps left  216
#   Time to finish  10s,   95.0% completed, time steps left  215
#   Time to finish  10s,   95.0% completed, time steps left  214
#   Time to finish  10s,   95.1% completed, time steps left  213
#   Time to finish  10s,   95.1% completed, time steps left  212
#   Time to finish  10s,   95.1% completed, time steps left  211
#   Time to finish  10s,   95.1% completed, time steps left  210
#   Time to finish   9s,   95.2% completed, time steps left  209
#   Time to finish   9s,   95.2% completed, time steps left  208
#   Time to finish   9s,   95.2% completed, time steps left  207
#   Time to finish   9s,   95.2% completed, time steps left  206
#   Time to finish   9s,   95.3% completed, time steps left  205
#   Time to finish   9s,   95.3% completed, time steps left  204
#   Time to finish   9s,   95.3% completed, time steps left  203
#   Time to finish   9s,   95.3% completed, time steps left  202
#   Time to finish   9s,   95.3% completed, time steps left  201
#   Time to finish   9s,   95.4% completed, time steps left  200
#   Time to finish   9s,   95.4% completed, time steps left  199
#   Time to finish   9s,   95.4% completed, time steps left  198
#   Time to finish   9s,   95.4% completed, time steps left  197
#   Time to finish   9s,   95.5% completed, time steps left  196
#   Time to finish   9s,   95.5% completed, time steps left  195
#   Time to finish   9s,   95.5% completed, time steps left  194
#   Time to finish   9s,   95.5% completed, time steps left  193
#   Time to finish   9s,   95.6% completed, time steps left  192
#   Time to finish   9s,   95.6% completed, time steps left  191
#   Time to finish   9s,   95.6% completed, time steps left  190
#   Time to finish   9s,   95.6% completed, time steps left  189
#   Time to finish   9s,   95.6% completed, time steps left  188
#   Time to finish   8s,   95.7% completed, time steps left  187
#   Time to finish   8s,   95.7% completed, time steps left  186
#   Time to finish   8s,   95.7% completed, time steps left  185
#   Time to finish   8s,   95.7% completed, time steps left  184
#   Time to finish   8s,   95.8% completed, time steps left  183
#   Time to finish   8s,   95.8% completed, time steps left  182
#   Time to finish   8s,   95.8% completed, time steps left  181
#   Time to finish   8s,   95.8% completed, time steps left  180
#   Time to finish   8s,   95.9% completed, time steps left  179
#   Time to finish   8s,   95.9% completed, time steps left  178
#   Time to finish   8s,   95.9% completed, time steps left  177
#   Time to finish   8s,   95.9% completed, time steps left  176
#   Time to finish   8s,   95.9% completed, time steps left  175
#   Time to finish   8s,   96.0% completed, time steps left  174
#   Time to finish   8s,   96.0% completed, time steps left  173
#   Time to finish   8s,   96.0% completed, time steps left  172
#   Time to finish   8s,   96.0% completed, time steps left  171
#   Time to finish   8s,   96.1% completed, time steps left  170
#   Time to finish   8s,   96.1% completed, time steps left  169
#   Time to finish   8s,   96.1% completed, time steps left  168
#   Time to finish   8s,   96.1% completed, time steps left  167
#   Time to finish   8s,   96.2% completed, time steps left  166
#   Time to finish   8s,   96.2% completed, time steps left  165
#   Time to finish   7s,   96.2% completed, time steps left  164
#   Time to finish   7s,   96.2% completed, time steps left  163
#   Time to finish   7s,   96.2% completed, time steps left  162
#   Time to finish   7s,   96.3% completed, time steps left  161
#   Time to finish   7s,   96.3% completed, time steps left  160
#   Time to finish   7s,   96.3% completed, time steps left  159
#   Time to finish   7s,   96.3% completed, time steps left  158
#   Time to finish   7s,   96.4% completed, time steps left  157
#   Time to finish   7s,   96.4% completed, time steps left  156
#   Time to finish   7s,   96.4% completed, time steps left  155
#   Time to finish   7s,   96.4% completed, time steps left  154
#   Time to finish   7s,   96.5% completed, time steps left  153
#   Time to finish   7s,   96.5% completed, time steps left  152
#   Time to finish   7s,   96.5% completed, time steps left  151
#   Time to finish   7s,   96.5% completed, time steps left  150
#   Time to finish   7s,   96.6% completed, time steps left  149
#   Time to finish   7s,   96.6% completed, time steps left  148
#   Time to finish   7s,   96.6% completed, time steps left  147
#   Time to finish   7s,   96.6% completed, time steps left  146
#   Time to finish   7s,   96.6% completed, time steps left  145
#   Time to finish   7s,   96.7% completed, time steps left  144
#   Time to finish   7s,   96.7% completed, time steps left  143
#   Time to finish   6s,   96.7% completed, time steps left  142
#   Time to finish   6s,   96.7% completed, time steps left  141
#   Time to finish   6s,   96.8% completed, time steps left  140
#   Time to finish   6s,   96.8% completed, time steps left  139
#   Time to finish   6s,   96.8% completed, time steps left  138
#   Time to finish   6s,   96.8% completed, time steps left  137
#   Time to finish   6s,   96.9% completed, time steps left  136
#   Time to finish   6s,   96.9% completed, time steps left  135
#   Time to finish   6s,   96.9% completed, time steps left  134
#   Time to finish   6s,   96.9% completed, time steps left  133
#   Time to finish   6s,   96.9% completed, time steps left  132
#   Time to finish   6s,   97.0% completed, time steps left  131
#   Time to finish   6s,   97.0% completed, time steps left  130
#   Time to finish   6s,   97.0% completed, time steps left  129
#   Time to finish   6s,   97.0% completed, time steps left  128
#   Time to finish   6s,   97.1% completed, time steps left  127
#   Time to finish   6s,   97.1% completed, time steps left  126
#   Time to finish   6s,   97.1% completed, time steps left  125
#   Time to finish   6s,   97.1% completed, time steps left  124
#   Time to finish   6s,   97.2% completed, time steps left  123
#   Time to finish   6s,   97.2% completed, time steps left  122
#   Time to finish   6s,   97.2% completed, time steps left  121
#   Time to finish   5s,   97.2% completed, time steps left  120
#   Time to finish   5s,   97.2% completed, time steps left  119
#   Time to finish   5s,   97.3% completed, time steps left  118
#   Time to finish   5s,   97.3% completed, time steps left  117
#   Time to finish   5s,   97.3% completed, time steps left  116
#   Time to finish   5s,   97.3% completed, time steps left  115
#   Time to finish   5s,   97.4% completed, time steps left  114
#   Time to finish   5s,   97.4% completed, time steps left  113
#   Time to finish   5s,   97.4% completed, time steps left  112
#   Time to finish   5s,   97.4% completed, time steps left  111
#   Time to finish   5s,   97.5% completed, time steps left  110
#   Time to finish   5s,   97.5% completed, time steps left  109
#   Time to finish   5s,   97.5% completed, time steps left  108
#   Time to finish   5s,   97.5% completed, time steps left  107
#   Time to finish   5s,   97.5% completed, time steps left  106
#   Time to finish   5s,   97.6% completed, time steps left  105
#   Time to finish   5s,   97.6% completed, time steps left  104
#   Time to finish   5s,   97.6% completed, time steps left  103
#   Time to finish   5s,   97.6% completed, time steps left  102
#   Time to finish   5s,   97.7% completed, time steps left  101
#   Time to finish   5s,   97.7% completed, time steps left  100
#   Time to finish   5s,   97.7% completed, time steps left  99
#   Time to finish   4s,   97.7% completed, time steps left  98
#   Time to finish   4s,   97.8% completed, time steps left  97
#   Time to finish   4s,   97.8% completed, time steps left  96
#   Time to finish   4s,   97.8% completed, time steps left  95
#   Time to finish   4s,   97.8% completed, time steps left  94
#   Time to finish   4s,   97.8% completed, time steps left  93
#   Time to finish   4s,   97.9% completed, time steps left  92
#   Time to finish   4s,   97.9% completed, time steps left  91
#   Time to finish   4s,   97.9% completed, time steps left  90
#   Time to finish   4s,   97.9% completed, time steps left  89
#   Time to finish   4s,   98.0% completed, time steps left  88
#   Time to finish   4s,   98.0% completed, time steps left  87
#   Time to finish   4s,   98.0% completed, time steps left  86
#   Time to finish   4s,   98.0% completed, time steps left  85
#   Time to finish   4s,   98.1% completed, time steps left  84
#   Time to finish   4s,   98.1% completed, time steps left  83
#   Time to finish   4s,   98.1% completed, time steps left  82
#   Time to finish   4s,   98.1% completed, time steps left  81
#   Time to finish   4s,   98.1% completed, time steps left  80
#   Time to finish   4s,   98.2% completed, time steps left  79
#   Time to finish   4s,   98.2% completed, time steps left  78
#   Time to finish   4s,   98.2% completed, time steps left  77
#   Time to finish   3s,   98.2% completed, time steps left  76
#   Time to finish   3s,   98.3% completed, time steps left  75
#   Time to finish   3s,   98.3% completed, time steps left  74
#   Time to finish   3s,   98.3% completed, time steps left  73
#   Time to finish   3s,   98.3% completed, time steps left  72
#   Time to finish   3s,   98.4% completed, time steps left  71
#   Time to finish   3s,   98.4% completed, time steps left  70
#   Time to finish   3s,   98.4% completed, time steps left  69
#   Time to finish   3s,   98.4% completed, time steps left  68
#   Time to finish   3s,   98.4% completed, time steps left  67
#   Time to finish   3s,   98.5% completed, time steps left  66
#   Time to finish   3s,   98.5% completed, time steps left  65
#   Time to finish   3s,   98.5% completed, time steps left  64
#   Time to finish   3s,   98.5% completed, time steps left  63
#   Time to finish   3s,   98.6% completed, time steps left  62
#   Time to finish   3s,   98.6% completed, time steps left  61
#   Time to finish   3s,   98.6% completed, time steps left  60
#   Time to finish   3s,   98.6% completed, time steps left  59
#   Time to finish   3s,   98.7% completed, time steps left  58
#   Time to finish   3s,   98.7% completed, time steps left  57
#   Time to finish   3s,   98.7% completed, time steps left  56
#   Time to finish   3s,   98.7% completed, time steps left  55
#   Time to finish   2s,   98.8% completed, time steps left  54
#   Time to finish   2s,   98.8% completed, time steps left  53
#   Time to finish   2s,   98.8% completed, time steps left  52
#   Time to finish   2s,   98.8% completed, time steps left  51
#   Time to finish   2s,   98.8% completed, time steps left  50
#   Time to finish   2s,   98.9% completed, time steps left  49
#   Time to finish   2s,   98.9% completed, time steps left  48
#   Time to finish   2s,   98.9% completed, time steps left  47
#   Time to finish   2s,   98.9% completed, time steps left  46
#   Time to finish   2s,   99.0% completed, time steps left  45
#   Time to finish   2s,   99.0% completed, time steps left  44
#   Time to finish   2s,   99.0% completed, time steps left  43
#   Time to finish   2s,   99.0% completed, time steps left  42
#   Time to finish   2s,   99.1% completed, time steps left  41
#   Time to finish   2s,   99.1% completed, time steps left  40
#   Time to finish   2s,   99.1% completed, time steps left  39
#   Time to finish   2s,   99.1% completed, time steps left  38
#   Time to finish   2s,   99.1% completed, time steps left  37
#   Time to finish   2s,   99.2% completed, time steps left  36
#   Time to finish   2s,   99.2% completed, time steps left  35
#   Time to finish   2s,   99.2% completed, time steps left  34
#   Time to finish   2s,   99.2% completed, time steps left  33
#   Time to finish   1s,   99.3% completed, time steps left  32
#   Time to finish   1s,   99.3% completed, time steps left  31
#   Time to finish   1s,   99.3% completed, time steps left  30
#   Time to finish   1s,   99.3% completed, time steps left  29
#   Time to finish   1s,   99.4% completed, time steps left  28
#   Time to finish   1s,   99.4% completed, time steps left  27
#   Time to finish   1s,   99.4% completed, time steps left  26
#   Time to finish   1s,   99.4% completed, time steps left  25
#   Time to finish   1s,   99.4% completed, time steps left  24
#   Time to finish   1s,   99.5% completed, time steps left  23
#   Time to finish   1s,   99.5% completed, time steps left  22
#   Time to finish   1s,   99.5% completed, time steps left  21
#   Time to finish   1s,   99.5% completed, time steps left  20
#   Time to finish   1s,   99.6% completed, time steps left  19
#   Time to finish   1s,   99.6% completed, time steps left  18
#   Time to finish   1s,   99.6% completed, time steps left  17
#   Time to finish   1s,   99.6% completed, time steps left  16
#   Time to finish   1s,   99.7% completed, time steps left  15
#   Time to finish   1s,   99.7% completed, time steps left  14
#   Time to finish   1s,   99.7% completed, time steps left  13
#   Time to finish   1s,   99.7% completed, time steps left  12
#   Time to finish   1s,   99.7% completed, time steps left  11
#   Time to finish   0s,   99.8% completed, time steps left  10
#   Time to finish   0s,   99.8% completed, time steps left  9
#   Time to finish   0s,   99.8% completed, time steps left  8
#   Time to finish   0s,   99.8% completed, time steps left  7
#   Time to finish   0s,   99.9% completed, time steps left  6
#   Time to finish   0s,   99.9% completed, time steps left  5
#   Time to finish   0s,   99.9% completed, time steps left  4
#   Time to finish   0s,   99.9% completed, time steps left  3
#   Time to finish   0s,  100.0% completed, time steps left  2
#   Time to finish   0s,  100.0% completed, time steps left  1
#
# ------------------------------------------------------------------------------
#   FINISHED    Delft3D-FLOW
#               runid      : eur025
#               date, time : 2018-05-07, 17:52:46
# SUMMARY FOR PARTITION :  1
# *** WARNING File will not be created - No output for HIS selected
# *** WARNING The file tri-rst.eur025.20100203.000000 for restart already exists,
# ***          written over
#     0 errors and     2 warnings
# returning to main program from domain eur025
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  2
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain eur025
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  3
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain eur025
# ------------------------------------------------------------------------------
# SUMMARY FOR PARTITION :  4
# *** WARNING File will not be created - No output for HIS selected
#     0 errors and     1 warnings
# returning to main program from domain eur025
# ------------------------------------------------------------------------------
# D_Hydro [1525708367.001800] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1525708367.001912] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1525708367.001987] <anonymous> >> d_hydro shutting down normally
# D_Hydro [1525708367.012882] <anonymous> >> d_hydro shutting down normally
# INFO:root:done for date :20100202.12

# %% [markdown]
# ## Analysis of data

# %%
# %matplotlib inline

# %%
folders = [info['path']+f for f in info['folders']]

# %%
folders
# Out:
# ['/Users/brey/Downloads/EUR/20100201.00',
#  '/Users/brey/Downloads/EUR/20100201.12',
#  '/Users/brey/Downloads/EUR/20100202.00',
#  '/Users/brey/Downloads/EUR/20100202.12']

# %%
out = []
for folder in folders:
    out.append(data([folder]))
# Out:
# reading data based on /Users/brey/Downloads/EUR/20100201.00/eur025_info.pkl
#
# reading data based on /Users/brey/Downloads/EUR/20100201.12/eur025_info.pkl
#
# reading data based on /Users/brey/Downloads/EUR/20100202.00/eur025_info.pkl
#
# reading data based on /Users/brey/Downloads/EUR/20100202.12/eur025_info.pkl

# %%
out[0].times, out[1].times
# Out:
# (array(['2010-02-01T00:00:00.000000000', '2010-02-01T01:00:00.000000000',
#         '2010-02-01T02:00:00.000000000', '2010-02-01T03:00:00.000000000',
#         '2010-02-01T04:00:00.000000000', '2010-02-01T05:00:00.000000000',
#         '2010-02-01T06:00:00.000000000', '2010-02-01T07:00:00.000000000',
#         '2010-02-01T08:00:00.000000000', '2010-02-01T09:00:00.000000000',
#         '2010-02-01T10:00:00.000000000', '2010-02-01T11:00:00.000000000',
#         '2010-02-01T12:00:00.000000000', '2010-02-01T13:00:00.000000000',
#         '2010-02-01T14:00:00.000000000', '2010-02-01T15:00:00.000000000',
#         '2010-02-01T16:00:00.000000000', '2010-02-01T17:00:00.000000000',
#         '2010-02-01T18:00:00.000000000', '2010-02-01T19:00:00.000000000',
#         '2010-02-01T20:00:00.000000000', '2010-02-01T21:00:00.000000000',
#         '2010-02-01T22:00:00.000000000', '2010-02-01T23:00:00.000000000',
#         '2010-02-02T00:00:00.000000000', '2010-02-02T01:00:00.000000000',
#         '2010-02-02T02:00:00.000000000', '2010-02-02T03:00:00.000000000',
#         '2010-02-02T04:00:00.000000000', '2010-02-02T05:00:00.000000000',
#         '2010-02-02T06:00:00.000000000', '2010-02-02T07:00:00.000000000',
#         '2010-02-02T08:00:00.000000000', '2010-02-02T09:00:00.000000000',
#         '2010-02-02T10:00:00.000000000', '2010-02-02T11:00:00.000000000',
#         '2010-02-02T12:00:00.000000000', '2010-02-02T13:00:00.000000000',
#         '2010-02-02T14:00:00.000000000', '2010-02-02T15:00:00.000000000',
#         '2010-02-02T16:00:00.000000000', '2010-02-02T17:00:00.000000000',
#         '2010-02-02T18:00:00.000000000', '2010-02-02T19:00:00.000000000',
#         '2010-02-02T20:00:00.000000000', '2010-02-02T21:00:00.000000000',
#         '2010-02-02T22:00:00.000000000', '2010-02-02T23:00:00.000000000',
#         '2010-02-03T00:00:00.000000000', '2010-02-03T01:00:00.000000000',
#         '2010-02-03T02:00:00.000000000', '2010-02-03T03:00:00.000000000',
#         '2010-02-03T04:00:00.000000000', '2010-02-03T05:00:00.000000000',
#         '2010-02-03T06:00:00.000000000', '2010-02-03T07:00:00.000000000',
#         '2010-02-03T08:00:00.000000000', '2010-02-03T09:00:00.000000000',
#         '2010-02-03T10:00:00.000000000', '2010-02-03T11:00:00.000000000',
#         '2010-02-03T12:00:00.000000000', '2010-02-03T13:00:00.000000000',
#         '2010-02-03T14:00:00.000000000', '2010-02-03T15:00:00.000000000',
#         '2010-02-03T16:00:00.000000000', '2010-02-03T17:00:00.000000000',
#         '2010-02-03T18:00:00.000000000', '2010-02-03T19:00:00.000000000',
#         '2010-02-03T20:00:00.000000000', '2010-02-03T21:00:00.000000000',
#         '2010-02-03T22:00:00.000000000', '2010-02-03T23:00:00.000000000',
#         '2010-02-04T00:00:00.000000000'], dtype='datetime64[ns]'),
#  array(['2010-02-01T12:00:00.000000000', '2010-02-01T13:00:00.000000000',
#         '2010-02-01T14:00:00.000000000', '2010-02-01T15:00:00.000000000',
#         '2010-02-01T16:00:00.000000000', '2010-02-01T17:00:00.000000000',
#         '2010-02-01T18:00:00.000000000', '2010-02-01T19:00:00.000000000',
#         '2010-02-01T20:00:00.000000000', '2010-02-01T21:00:00.000000000',
#         '2010-02-01T22:00:00.000000000', '2010-02-01T23:00:00.000000000',
#         '2010-02-02T00:00:00.000000000', '2010-02-02T01:00:00.000000000',
#         '2010-02-02T02:00:00.000000000', '2010-02-02T03:00:00.000000000',
#         '2010-02-02T04:00:00.000000000', '2010-02-02T05:00:00.000000000',
#         '2010-02-02T06:00:00.000000000', '2010-02-02T07:00:00.000000000',
#         '2010-02-02T08:00:00.000000000', '2010-02-02T09:00:00.000000000',
#         '2010-02-02T10:00:00.000000000', '2010-02-02T11:00:00.000000000',
#         '2010-02-02T12:00:00.000000000', '2010-02-02T13:00:00.000000000',
#         '2010-02-02T14:00:00.000000000', '2010-02-02T15:00:00.000000000',
#         '2010-02-02T16:00:00.000000000', '2010-02-02T17:00:00.000000000',
#         '2010-02-02T18:00:00.000000000', '2010-02-02T19:00:00.000000000',
#         '2010-02-02T20:00:00.000000000', '2010-02-02T21:00:00.000000000',
#         '2010-02-02T22:00:00.000000000', '2010-02-02T23:00:00.000000000',
#         '2010-02-03T00:00:00.000000000', '2010-02-03T01:00:00.000000000',
#         '2010-02-03T02:00:00.000000000', '2010-02-03T03:00:00.000000000',
#         '2010-02-03T04:00:00.000000000', '2010-02-03T05:00:00.000000000',
#         '2010-02-03T06:00:00.000000000', '2010-02-03T07:00:00.000000000',
#         '2010-02-03T08:00:00.000000000', '2010-02-03T09:00:00.000000000',
#         '2010-02-03T10:00:00.000000000', '2010-02-03T11:00:00.000000000',
#         '2010-02-03T12:00:00.000000000', '2010-02-03T13:00:00.000000000',
#         '2010-02-03T14:00:00.000000000', '2010-02-03T15:00:00.000000000',
#         '2010-02-03T16:00:00.000000000', '2010-02-03T17:00:00.000000000',
#         '2010-02-03T18:00:00.000000000', '2010-02-03T19:00:00.000000000',
#         '2010-02-03T20:00:00.000000000', '2010-02-03T21:00:00.000000000',
#         '2010-02-03T22:00:00.000000000', '2010-02-03T23:00:00.000000000',
#         '2010-02-04T00:00:00.000000000', '2010-02-04T01:00:00.000000000',
#         '2010-02-04T02:00:00.000000000', '2010-02-04T03:00:00.000000000',
#         '2010-02-04T04:00:00.000000000', '2010-02-04T05:00:00.000000000',
#         '2010-02-04T06:00:00.000000000', '2010-02-04T07:00:00.000000000',
#         '2010-02-04T08:00:00.000000000', '2010-02-04T09:00:00.000000000',
#         '2010-02-04T10:00:00.000000000', '2010-02-04T11:00:00.000000000',
#         '2010-02-04T12:00:00.000000000'], dtype='datetime64[ns]'))

# %%
out[0].dem.bathymetry.plot()

# %%
out[0].obs.locations
# Out:
#       ID                              Name      Group Latency  Details  \
# 0   2576              Denmark -Hunderstend        DMI     11m  Details
# 1   1044        Tamosy Large Panel (Press)        TAD     11m  Details
# 2    894              Denmark - Hirtshals   TD UNESCO   1h 1m  Details
# 3   1284                    France - Brest  TD UNESCO     58m  Details
# 4   1444                  France - Calais   TD UNESCO     58m  Details
# 5   1289                France - Cherbourg  TD UNESCO     58m  Details
# 6   1511  Germany - Helgoland Binnenhafen   TD UNESCO     46m  Details
# 7   1703                   Norway - Tregde  TD UNESCO     41m  Details
# 8    831               Portugal - Cascais   TD UNESCO  4h 49m  Details
# 9    873                  Spain - Ferrol1   TD UNESCO     43m  Details
# 10   886      Sweden - GoteborgTorshamnen   TD UNESCO  1h 42m  Details
#
#              Last Date           Max. Time           Min. Time     lat  \
# 0    09 Apr 2018 11:30   28 Aug 2017 10:10   01 Jan 2010 00:05  55.966
# 1    20 Jun 2030 05:01   05 Aug 2062 21:01   11 Jan 2000 00:03  46.500
# 2    09 Apr 2018 10:40   09 Apr 2018 10:40   31 Dec 2009 00:10  57.600
# 3    09 Apr 2018 10:42   09 Apr 2018 10:42   01 Jan 2010 00:01  48.380
# 4    09 Apr 2018 10:42   09 Apr 2018 10:42   01 Jan 2010 00:01  50.969
# 5    09 Apr 2018 10:42   09 Apr 2018 10:42   01 Jan 2010 00:01  49.650
# 6    09 Apr 2018 10:55   09 Apr 2018 10:55   01 Jan 2005 00:01  54.176
# 7    09 Apr 2018 11:00   09 Apr 2018 09:00   01 Jan 2010 00:10  58.000
# 8    09 Apr 2018 06:51   09 Apr 2018 06:51   01 Jan 2010 00:04  38.693
# 9    09 Apr 2018 10:58   09 Apr 2018 08:58   02 Jan 2010 00:01  43.460
# 10   09 Apr 2018 09:59   09 Apr 2018 07:57   01 Jan 2010 00:05  57.683
#
#        lon  Status
# 0   11.843  Active
# 1    8.617  Active
# 2    9.970  Active
# 3   -4.500  Active
# 4    1.868  Active
# 5   -1.630  Active
# 6    7.891  Active
# 7    7.567  Active
# 8   -9.000  Active
# 9   -8.330  Active
# 10  11.783  Active

# %%
 plat,plon = out[0].obs.locations.loc[6,['lat','lon']]

# %%
p6=[]
for i in range(len(out)):
    ts = point(lon=plon,lat=plat,data=out[i])
    ts.tseries(var='S1')
    p6.append(ts.S1)

# %%
p = out[0].obs.iloc(6)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
ax=p['Storm Surge'].plot()
for i in range(len(out)):
    p6[i].plot(ax=ax)
plt.legend(['tide gauge'] + info['folders'])
